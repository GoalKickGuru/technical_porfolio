# %% [markdown]
# # Skeleton Notebook: Data Types, Distributions & Resampling
#
# Practice this lab **from scratch**. Every module gives you the goal and a scaffold
# — fill in the `# TODO` lines yourself. No solutions here; see `4_solutions_notebook.ipynb`
# if you get stuck, and `2_cheat_sheet.ipynb` for quick syntax lookups.
#
# Work through the modules in order — later modules assume variables from earlier ones.

# %%
# TODO: import numpy as np, pandas as pd, scipy.stats as stats, matplotlib.pyplot as plt,
# statsmodels.api as sm, and permutations/combinations from itertools.
# Also set a random seed for reproducibility.

# %% [markdown]
# ---
# ## Module 1 — Types of Data
#
# **Goal:** classify data and visualize nominal vs. ordinal vs. interval vs. ratio data.

# %% [markdown]
# **TODO 1.1:** Classify each variable as nominal, ordinal, interval, or ratio
# (one sentence justification each):
# 1. Customer satisfaction: "Unhappy", "Neutral", "Happy"
# 2. Zip code
# 3. Number of children in a household
# 4. Credit score (300–850)
# 5. Marathon finishing time in minutes
#
# _Your answer here._

# %% [markdown]
# **TODO 1.2:** Create a bar chart for ordinal data — movie ratings
# `['G', 'PG', 'PG-13', 'R']` with counts `[12, 30, 45, 18]`. Preserve natural order
# on the x-axis, and label the axes/title.

# %%
# TODO 1.2

# %% [markdown]
# **TODO 1.3:** Generate 3000 samples of skewed "wait time" data using
# `scipy.stats.skewnorm.rvs(a=4, size=3000)`, shift it by `+0.5`, keep only positive
# values, and plot a histogram. Is this nominal, ordinal, interval, or ratio data? Why?

# %%
# TODO 1.3

# %% [markdown]
# ---
# ## Module 2 — Descriptive Statistics & Normal Distribution
#
# **Goal:** compute center/variability/shape statistics, then explore the Empirical
# Rule and the Central Limit Theorem (CLT) via simulation.

# %% [markdown]
# **TODO 2.1:** For `values = [85, 99, 70, 71, 86, 88, 94]`, compute:
# mean, median, mode, variance (sample, ddof=1), standard deviation, Q1/Q2/Q3, and IQR.
# Print each with a label.

# %%
values = [85, 99, 70, 71, 86, 88, 94]
# TODO 2.1

# %% [markdown]
# **TODO 2.2:** Using the Q1/Q3/IQR from above, compute the Tukey fences
# (`k=1.5`) and state whether any of the 7 values in `values` would be flagged as an
# outlier.

# %%
# TODO 2.2

# %% [markdown]
# **TODO 2.3:** Generate three synthetic distributions of size 3000 using
# `scipy.stats.skewnorm` (one left-skewed, one right-skewed) and `scipy.stats.norm`
# (symmetric). Compute `stats.skew` and `stats.kurtosis` for each and print them.

# %%
# TODO 2.3

# %% [markdown]
# **TODO 2.4 — Empirical Rule:** Generate 200,000 standard normal values
# (`np.random.randn`). Compute the mean and std, then verify empirically what
# fraction of values fall within 1, 2, and 3 standard deviations of the mean.
# Compare to the theoretical 68% / 95% / 99.7%.

# %%
# TODO 2.4

# %% [markdown]
# **TODO 2.5 — CLT demo:** Create a population of 1,000,000 values drawn from
# `np.random.exponential(scale=2.0, ...)` (very non-normal). For sample sizes
# `n = 5, 30, 100`, repeatedly (3000 times) draw a random sample of size `n` from the
# population, record its mean, and plot a histogram of those 3000 means. What
# happens to the shape as `n` increases?

# %%
# TODO 2.5

# %% [markdown]
# ---
# ## Module 3 — Bootstrapping
#
# **Goal:** use bootstrapping (resampling with replacement) to build confidence
# intervals for a mean, a correlation, and to compare two groups.

# %% [markdown]
# **TODO 3.1:** Load the Duncan dataset:
# ```python
# df_duncan = sm.datasets.get_rdataset("Duncan", "carData").data
# ```
# Recode `type` values `'prof'`, `'wc'`, `'bc'` to `'professional'`, `'white-collar'`,
# `'blue-collar'`. Create two sub-DataFrames: `df_professional` and `df_blue_collar`.

# %%
# TODO 3.1

# %% [markdown]
# **TODO 3.2:** Write a function
# `bootstrap_means(sample, n_replicas=10000, frac=0.5, replace=True, seed=None)`
# that returns a NumPy array of `n_replicas` bootstrap means. Use it to bootstrap the
# `income` column for both `df_professional` and `df_blue_collar`. Then compute and
# print the 95% confidence interval (2.5th and 97.5th percentiles) for each. Do the
# CIs overlap?

# %%
# TODO 3.2

# %% [markdown]
# **TODO 3.3:** Plot histograms of both bootstrap distributions from 3.2 in a
# 2x1 subplot grid, with vertical lines for the mean and the two CI bounds.

# %%
# TODO 3.3

# %% [markdown]
# **TODO 3.4:** Bootstrap the Pearson correlation between `education` and
# `income` across the full `df_duncan` dataset (resample rows with replacement, 5000
# times, recompute `scipy.stats.pearsonr` each time). Report the mean bootstrapped
# correlation and its 95% CI.

# %%
# TODO 3.4

# %% [markdown]
# ---
# ## Module 4 — Permutations, Combinations & Permutation Testing
#
# **Goal:** count arrangements/selections, then use permutation testing as a
# non-parametric hypothesis test.

# %% [markdown]
# **TODO 4.1:** For a list of 10 people `['P1', ..., 'P10']`, use
# `itertools.permutations` to count ordered selections of 3, `itertools.combinations`
# to count unordered selections of 3, and `itertools.permutations` (no second
# argument) to count full orderings of all 10. Verify against the closed-form
# formulas `P(n,r)` and `C(n,r)`.

# %%
# TODO 4.1

# %% [markdown]
# **TODO 4.2:** Write a function
# `permutation_test(A, B, n_iter=10000, seed=None, alternative='greater')` that:
# 1. Computes the observed difference in means `mean(A) - mean(B)`.
# 2. Pools A and B, then repeatedly shuffles and re-splits into groups the same
#    size as A and B, recording the difference in means each time.
# 3. Returns a p-value based on how extreme the observed difference is relative to
#    the shuffled (null) distribution, given the chosen `alternative`
#    (`'greater'`, `'less'`, or `'two-sided'`).
#
# Test it on `A = [3, 5, 4]`, `B = [43, 41, 56, 78, 54]` with `alternative='greater'`.

# %%
# TODO 4.2

# %% [markdown]
# **TODO 4.3:** Apply your `permutation_test` function to compare `income`
# between the `professional` and `blue-collar` groups in `df_duncan` (two-sided).
# Report the p-value and interpret it in one sentence.

# %%
# TODO 4.3

# %% [markdown]
# ---
# ## Module 5 — Transformations
#
# **Goal:** apply log/sqrt/cbrt/Box-Cox transformations to reduce skew.

# %% [markdown]
# **TODO 5.1:** Generate `df = np.random.beta(a=1, b=10, size=10000)` (strongly
# right-skewed). Compute `np.log`, `np.sqrt`, and `np.cbrt` transforms. Plot all four
# (original + 3 transforms) as histograms in a 2x2 grid, with the skewness value in
# each subplot's title.

# %%
# TODO 5.1

# %% [markdown]
# **TODO 5.2:** Apply `scipy.stats.boxcox` to `df` (add a tiny constant first
# so all values are strictly positive) and report the chosen lambda and the skewness
# before/after.

# %%
# TODO 5.2

# %% [markdown]
# **TODO 5.3:** Apply `np.log1p` to `df_duncan['income']`. Plot before/after
# histograms and report skewness before/after. Did the transform help?

# %%
# TODO 5.3

# %% [markdown]
# ---
# ## Module 6 — Capstone
#
# **Scenario:** You want to know whether **Model B** machine output differs from
# **Model C** machine output, with only 12 Model B and 9 Model C readings (ratio data).
#
# **TODO 6.1:**
# 1. Simulate the two samples (pick distributions/means of your choice; make at
#    least one of them skewed).
# 2. Classify the data type and state which statistics are valid.
# 3. Visualize both samples and report skewness/kurtosis.
# 4. If skewed, transform and re-check.
# 5. Run a permutation test for a difference in means.
# 6. Bootstrap a 95% CI for each group's mean and for the difference in means.
# 7. Write 3–4 sentences summarizing your conclusion and caveats.

# %%
# TODO 6.1 — capstone
