# %% [markdown]
# # Skeleton Lab: Survival Analysis in Python
# ### Practice from scratch — Kaplan-Meier, Exponential, Cox Proportional Hazards
#
# Fill in every `# TODO` cell. Do not look at `05_Detailed_Solutions.ipynb` until you've made a genuine
# attempt — the point of this notebook is retrieval practice, not transcription.
#
# **Datasets:** `larynx` (lifelines) and `heart` (statsmodels R datasets).
#
# ```
# pip install lifelines==0.27.4 statsmodels pandas matplotlib numpy --break-system-packages
# ```

# %% [markdown]
# ## Part 0 — Setup
# Import the libraries you'll need. Think about what you used for fitting, plotting, and statistical testing in each of the three model families.

# %%
# TODO: import pandas, numpy, matplotlib.pyplot
# TODO: import datasets, KaplanMeierFitter, ExponentialFitter, WeibullFitter, LogNormalFitter, CoxPHFitter from lifelines
# TODO: import logrank_test, multivariate_logrank_test from lifelines.statistics
# TODO: import concordance_index from lifelines.utils
# TODO: import statsmodels.api as sm

# %% [markdown]
# ## Part 1 — Kaplan-Meier Estimator
#
# ### 1.1 Load the `larynx` dataset from lifelines and inspect the first few rows.

# %%
# TODO: load the larynx dataset into `data`
# TODO: display data.head()

# %% [markdown]
# **Q1.1** — What do the columns `time`, `age`, `death`, `Stage_II`, `Stage_III`, `Stage_IV` represent? What does it mean if all three stage columns are 0?

# %%
# your written answer as a comment, or add a markdown cell

# %% [markdown]
# ### 1.2 Fit an overall Kaplan-Meier curve on `time` and `death`, then plot it with its 95% confidence band.

# %%
# TODO: instantiate a KaplanMeierFitter and call .fit(...)
# TODO: plot the survival function with a shaded confidence interval

# %% [markdown]
# **Q1.2** — Report the median survival time. Report S(t) at t = 60 months.

# %%
# TODO: use kmf.median_survival_time_ and kmf.predict(60)

# %% [markdown]
# ### 1.3 Split patients into `older` (age >= 65) and `younger` (age < 65) groups. Fit a separate Kaplan-Meier curve for each group and plot them on one axis.

# %%
# TODO: create an 'older' 0/1 column on `data`
# TODO: fit two KaplanMeierFitter objects, one per group
# TODO: plot both curves together

# %% [markdown]
# **Q1.3** — Run a log-rank test comparing the two age groups. State the null hypothesis, the p-value, and your conclusion at alpha = 0.05.

# %%
# TODO: from lifelines.statistics import logrank_test
# TODO: run the test and print the summary

# %% [markdown]
# ### 1.4 Split patients into four groups by cancer stage (I, II, III, IV) and plot all four Kaplan-Meier curves on one axis.

# %%
# TODO: derive a Stage_I indicator (1 when Stage_II, Stage_III, Stage_IV are all 0)
# TODO: fit one KaplanMeierFitter per stage
# TODO: plot all four curves

# %% [markdown]
# **Q1.4** — Run a multivariate log-rank test across all four stage groups simultaneously. Is there a significant difference somewhere among the four groups?

# %%
# TODO: from lifelines.statistics import multivariate_logrank_test
# TODO: build the durations/events/groups arrays and run the test

# %% [markdown]
# ## Part 2 — Exponential Model
#
# ### 2.1 Fit an `ExponentialFitter` to the whole `larynx` cohort. Plot it against the Kaplan-Meier curve
# from Part 1 on the same axis.

# %%
# TODO: fit an ExponentialFitter
# TODO: plot it together with the Kaplan-Meier curve (kmf) for comparison

# %% [markdown]
# **Q2.1** — What is the fitted rate parameter lambda? What is the implied mean survival time? Does the exponential curve track the Kaplan-Meier step function closely, or diverge in places? Where?

# %%
# your written answer

# %% [markdown]
# ### 2.2 Fit Weibull and LogNormal models to the same data. Compare all three (Exponential, Weibull, LogNormal) using AIC.

# %%
# TODO: fit WeibullFitter and LogNormalFitter
# TODO: print AIC_ for each of the three fitted models, sorted best-to-worst

# %% [markdown]
# **Q2.2** — Which model wins by AIC? What does this tell you about whether the constant-hazard assumption behind the exponential model is reasonable for this dataset?

# %%
# your written answer

# %% [markdown]
# ## Part 3 — Cox Proportional Hazards on `larynx`
#
# ### 3.1 Build a Cox PH model using `age`, `Stage_II`, `Stage_III`, `Stage_IV` as covariates, with
# `time`/`death` as duration/event columns.

# %%
# TODO: assemble the modeling dataframe
# TODO: instantiate and fit a CoxPHFitter
# TODO: call .print_summary()

# %% [markdown]
# **Q3.1** — Which covariates are significant at the 5% level? Convert `exp(coef)` for each significant stage variable into a plain hazard-ratio sentence.

# %%
# your written answer

# %% [markdown]
# ### 3.2 Check the proportional hazards assumption for this model.

# %%
# TODO: call .check_assumptions(...) on the fitted model, passing the same dataframe

# %% [markdown]
# **Q3.2** — Does any covariate fail the check? What would you consider doing about it (you do not need to implement a fix)?

# %%
# your written answer

# %% [markdown]
# ## Part 4 — Cox Proportional Hazards on the Stanford Heart Transplant Data
#
# ### 4.1 Load the `heart` dataset from `statsmodels`'s R datasets (`survival` package). Split the first
# 171 rows into `train_data` and the remainder into `test_data`.

# %%
# TODO: heart = sm.datasets.get_rdataset(...).data
# TODO: train_data = ..., test_data = ...

# %% [markdown]
# ### 4.2 Fit Kaplan-Meier curves separately for `transplant == 0` and `transplant == 1` using `stop` as duration and `event` as the event indicator. Plot both.

# %%
# TODO

# %% [markdown]
# **Q4.2** — Read off (or predict) the survival probability at day 300 for each group. Which group appears to survive longer, based on the curves alone?

# %%
# your written answer

# %% [markdown]
# ### 4.3 Run a log-rank test between the transplant and no-transplant groups.

# %%
# TODO

# %% [markdown]
# ### 4.4 Fit a Cox PH model on `train_data` using `age`, `year`, `surgery`, `transplant` as covariates.

# %%
# TODO

# %% [markdown]
# **Q4.4** — Which covariates are significant? State the hazard-ratio interpretation for `transplant` and for `age`.

# %%
# your written answer

# %% [markdown]
# ### 4.5 Check the proportional hazards assumption for this model.

# %%
# TODO

# %% [markdown]
# ### 4.6 Compute the concordance index for the fitted model on `train_data`.

# %%
# TODO: use concordance_index(...) — remember predict_partial_hazard needs a sign flip

# %% [markdown]
# **Q4.6** — What does a concordance index of 0.5 mean? What does 1.0 mean? Is your model's value closer to 'useless' or 'perfect'?

# %%
# your written answer

# %% [markdown]
# ### 4.7 Predict and plot the survival function for the holdout patient(s) in `test_data`.

# %%
# TODO

# %% [markdown]
# ## Part 5 — Synthesis
#
# **Q5.1** — Complete this comparison table from memory (no peeking at your Part 1-4 code):
#
# | Question | Kaplan-Meier | Exponential | Cox PH |
# |---|---|---|---|
# | Handles covariates? | | | |
# | Assumes a hazard shape? | | | |
# | Gives a single interpretable effect size? | | | |
# | Assumption you must check before trusting it? | | | |
# | Best used for... | | | |
#
# **Q5.2** — Is the `transplant` hazard ratio you estimated in Part 4 a causal estimate? Why or why not?
#
# **Q5.3** — Both datasets you used here are small (n=90 and n=103). What does that imply about how much
# you should trust (a) the confidence bands in Part 1, (b) the Cox coefficients in Parts 3-4, and (c) the
# proportional-hazards checks?

# %% [markdown]
# _Your answers here._
