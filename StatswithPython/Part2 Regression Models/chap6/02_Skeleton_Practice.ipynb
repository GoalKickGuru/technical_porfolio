# %% [markdown]
# # Skeleton Notebook: Simple Linear Regression with OLS (Practice From Scratch)
#
# Fill in every `# TODO` below without looking at the Extended Lab or Solutions
# notebooks first. Use `00_Background_Theory.md` and the `02_Cheat_Sheet.ipynb`
# if you get stuck on syntax — the goal here is to practice the *workflow*,
# not to memorize statsmodels function names.
#
# **Structure** (mirrors the Extended Lab):
# - Part A: OLS from scratch on synthetic data
# - Part B: Correlation & determination
# - Part C: The four assumptions (controlled synthetic examples)
# - Part D: Real data — fit and read a statsmodels summary
# - Part E: Diagnostic plot suite
# - Part F: Serial correlation & differencing
# - Part G: Train/test validation vs. a naive baseline
# - Part H: Open-ended extension exercises

# %%
# TODO: import the libraries you'll need.
# You will need at least: numpy, pandas, seaborn, statsmodels.api,
# matplotlib.pyplot, scipy.stats.skewnorm, statsmodels' lowess smoother,
# plot_acf/plot_pacf, sklearn's train_test_split and mean_absolute_error.

RNG = np.random.default_rng(2022)  # keep this seed for reproducibility

# %% [markdown]
# ## Part A — OLS From Scratch

# %%
# TODO: Generate synthetic data from a KNOWN model: y = 2x + 3 + noise
# - x: 50 evenly spaced points from 0 to 10 (np.linspace)
# - noise: standard normal noise, 50 points, using RNG
# - y = 2*x + 3 + noise

# TODO: Plot the scatter of (x, y) along with the TRUE line y = 2x + 3 (no noise)

# %%
def least_squares_method(x, y):
    """
    TODO: implement the OLS closed-form estimator from the normal equations:
        beta1_hat = sum((x_i - x_mean)*(y_i - y_mean)) / sum((x_i - x_mean)**2)
        beta0_hat = y_mean - beta1_hat * x_mean
    Return (beta0_hat, beta1_hat).
    """
    pass

# TODO: call least_squares_method(x, y) and print both estimates.
# Compare them to the TRUE values (beta0=3, beta1=2).

# %% [markdown]
# 🧠 **Think About It:** Write 2-3 sentences: how close were your estimates to the true values, and what do you think would happen if you doubled `n` or doubled the noise's standard deviation?

# %%
# (optional) exploratory code for the Think About It question

# %% [markdown]
# ## Part B — Coefficients of Correlation and Determination

# %%
# TODO: Fit an OLS model with statsmodels for the same x, y from Part A.
#   Remember: statsmodels requires an explicit constant column -- use sm.add_constant.

# TODO: Compute r (Pearson correlation) with np.corrcoef, then r**2.
# TODO: Compute r^2 manually via 1 - SS_res/SS_tot using the fitted model's residuals.
# TODO: Compare both of your manual r^2 values to model.rsquared. Do they match?

# %% [markdown]
# ## Part C — The Four Assumptions (Synthetic Demonstrations)

# %% [markdown]
# ### C.1 Linearity

# %%
# TODO: Using scipy.stats.skewnorm.rvs(a=10, size=300), generate a skewed x variable, sorted.
# Build THREE y variables from the same x + shared standard-normal noise:
#   1. y_lin  = 4*x + 3 + noise          (linear)
#   2. y_quad = x**2 - 5 + noise         (quadratic)
#   3. y_none = noise                    (no relationship to x)
#
# TODO: Plot all three as scatter plots side-by-side, each with its TRUE
# (noise-free) function overlaid as a black line.

# %% [markdown]
# ### C.2 Normality of residuals despite skewed inputs

# %%
# TODO: Plot histograms of x and y_lin to show they are skewed.
# TODO: Fit an OLS model of y_lin on x (with constant).
# TODO: Plot a histogram of the model's residuals. Do they look roughly Normal
# even though the raw x, y_lin were skewed?

# %% [markdown]
# ### C.3 Homoscedasticity, and two ways to break it

# %%
# TODO: Plot residuals vs. fitted values for the y_lin model above.
# It should look like a random, constant-width scatter around 0.

# TODO: Break #1 -- create x_with_outlier: a copy of x with the LAST value
# forced to 5. Refit OLS with this x. Plot residuals vs fitted again.

# TODO: Break #2 -- create noise whose variance GROWS with index i
# (e.g., RNG.normal(0, i/20) for each i in range(len(x))). Add this to y_lin.
# Refit OLS. Plot residuals vs. fitted. You should see a "funnel" shape.

# %% [markdown]
# 🧠 **Think About It:** Describe, in your own words, how the outlier-driven and variance-growth-driven residual plots differ visually, and why a single global fix (like dropping the max residual) wouldn't work for both cases.

# %% [markdown]
# ### C.4 Independence -- no plot here, just reasoning

# %% [markdown]
# TODO (markdown answer): In 2-3 sentences, explain why independence of observations can't generally be verified from a residual plot the way linearity/normality/homoscedasticity can.

# %% [markdown]
# ## Part D — Real Data: statsmodels macrodata

# %%
# TODO: Load sm.datasets.macrodata.load().data into df.
# TODO: Add a constant column using sm.add_constant(df, prepend=False).
# TODO: Subset df down to just ['realinv', 'realdpi', 'const'] as df_mod.
# TODO: Plot histograms of realinv and realdpi.

# %%
# TODO: Make a scatter plot: realdpi (x-axis) vs realinv (y-axis).

# %%
# TODO: Fit sm.OLS with realdpi as the dependent variable and
# ['const', 'realinv'] as the independent variables. Print the .summary().

# %% [markdown]
# 🧠 **Think About It:** From the summary table, answer:
# 1. Is `realinv` statistically significant? What's the p-value and what does it mean?
# 2. What is R-squared, and in plain English, what does it say about this model?
# 3. What is the Durbin-Watson statistic here, and roughly what does a value that low suggest?

# %% [markdown]
# ## Part E — Diagnostic Plot Suite

# %%
# TODO: Extract from the fitted model in Part D:
#   - model_residuals   (.resid)
#   - fitted_value      (.fittedvalues)
#   - standardized_residuals  (.resid_pearson)
#   - sqrt_standardized_residuals (sqrt of abs of .get_influence().resid_studentized_internal)
#   - leverage          (.get_influence().hat_matrix_diag)
#   - cooks_distance    (.get_influence().cooks_distance[0])

# TODO: Build a 2x2 grid of plots:
#   [0,0] Residuals vs. Fitted, with a lowess smoothed trend line and horizontal reference at 0
#   [0,1] Normal Q-Q plot (sm.qqplot with fit=True, line='45')
#   [1,0] Scale-Location: sqrt_standardized_residuals vs fitted_value, with lowess trend
#   [1,1] Residuals vs. Leverage: standardized_residuals vs leverage, with lowess trend,
#         horizontal reference lines at 0, +3, -3, and annotate any points with
#         Cook's distance > 0.5

# %% [markdown]
# 🧠 **Think About It:** For each of the four panels, write one sentence describing what you actually observe (not the general theory -- the specific shape in front of you).

# %% [markdown]
# ## Part F — Serial Correlation: Durbin-Watson, ACF/PACF, Differencing

# %%
# TODO: Plot the PACF of the Part D model's residuals (plot_pacf, alpha=0.05, lags=50).
# What lag(s) show significant correlation?

# %%
# TODO: Build a 2x3 grid comparing the ORIGINAL vs. ONCE-DIFFERENCED realdpi series:
#   Row 0: ACF of realdpi | PACF of realdpi | line plot of realdpi
#   Row 1: ACF of diff(realdpi, n=1) | PACF of diff(realdpi, n=1) | line plot of diff(realdpi, n=1)

# %%
# TODO: Refit an OLS model using the DIFFERENCED realdpi as the target and
# DIFFERENCED realinv as the predictor. Remember: differencing drops one
# observation, so you must also drop one row from the constant column
# (e.g. df_mod['const'].iloc[:-1]).
# Print the summary. Compare R-squared and Durbin-Watson to the levels model
# from Part D.

# %% [markdown]
# 🧠 **Think About It:**
# 1. Why did R-squared change so much after differencing?
# 2. Using the Durbin-Watson critical value bounds from the background reading, is there
#    still evidence of autocorrelation after differencing? In which direction (positive/negative)?
# 3. Would you trust this differenced OLS model's p-values as a final answer, or would you
#    want to reach for a dedicated time-series model? Why?

# %% [markdown]
# ## Part G — Model Validation: Train/Test Split & Naive Baseline

# %%
# TODO: Using sklearn's train_test_split, split df_mod into train (75%) and
# test (25%) sets with shuffle=True.
# TODO: Fit an OLS model of realdpi ~ const + realinv on TRAIN only. Print summary.
# TODO: Fit a SEPARATE OLS model of realdpi ~ const + realinv on TEST only. Print summary.
# Compare the two sets of coefficients, standard errors, and R-squared -- are they similar?

# %%
# TODO: Compute four numbers using mean_absolute_error and simple mean-based comparisons:
#   1. MAE of the train-fitted model's predictions on the TRAIN set
#   2. MAE of a naive "always predict train mean" model on the TRAIN set
#   3. MAE of the train-fitted model's predictions on the TEST (holdout) set
#   4. MAE of a naive "always predict test mean" model on the TEST set
# Print all four and compare.

# %% [markdown]
# ## Part H — Open-Ended Extension Exercises
#
# Attempt as many as you can without referring to the Solutions notebook:
#
# 1. **Simulation study.** Loop 500 times: generate `y = 2x + 3 + N(0, sigma)`
#    with `n=30`, fit OLS, store `beta1_hat`. Plot a histogram of the 500
#    estimates. Try different `sigma` and `n` values.
# 2. **Robust standard errors.** Refit the Part D model with
#    `.fit(cov_type='HC3')`. Compare std errors / p-values to the default fit.
# 3. **Alternative predictor.** Try predicting `realdpi` from a different
#    macrodata column (e.g. `realgdp`). Repeat the Part D-E workflow.
# 4. **Outlier sensitivity.** Compare `beta1_hat` with and without the
#    Part C.3 outlier point. How much does it move?
# 5. **Re-derive from memory.** Without looking anything up, re-derive and
#    re-implement `least_squares_method` from the normal equations.
