# %% [markdown]
# # Currency Converter - Practice Skeleton
#
# **Project:** Chapter 14 Currency Converter (Hassan S. *Learn Python by Doing*)
# **Goal:** Implement an extended currency converter yourself, then compare with the Solution notebook.
#
# You will build:
# - Offline exchange-rate table + rate loader (API fallback optional)
# - Single & multi-currency conversion
# - Conversion history
# - Alternate dictionary-of-lambdas implementation
# - Extra practice drills
# - Parameterised Monte-Carlo simulation of rate noise
#
# ## Flowchart of the Desired Outcome
# ![Currency Converter Flowchart](currency_converter_flowchart.png)
#
# Follow the TODOs. Every code cell ends with a small print so you can verify progress.

# %% [markdown]
# ## 0. Imports
#
# Import the libraries you will need.

# %%
# TODO: import numpy, matplotlib.pyplot, typing helpers (Dict, List, Optional, Callable), datetime
# YOUR CODE HERE

print("Libraries imported.")

# %% [markdown]
# ## 1. Offline Exchange-Rate Table & Rate Loader
#
# 1. Create a dictionary `RATES_USD` that maps currency codes to their value relative to 1 USD.
#    Include at least: USD, EUR, GBP, JPY, INR, CRC, CAD, AUD, CHF, CNY.
# 2. Write `get_exchange_rates(base_currency="USD", use_api=False)` that:
#    - returns a dict of rates **relative to the requested base**,
#    - caches the result,
#    - optionally tries a live API and falls back to the offline table on any error.

# %%
# TODO: define RATES_USD, SUPPORTED, _rate_cache, _history

RATES_USD = {
    # "USD": 1.00,
    # ... fill the rest
}

# TODO: implement get_exchange_rates
def get_exchange_rates(base_currency: str = "USD", use_api: bool = False):
    # YOUR CODE HERE
    pass

print("Supported currencies:", sorted(RATES_USD.keys()) if RATES_USD else "TODO")

# %% [markdown]
# ## 2. Core Conversion Functions
#
# Implement:
#
# - `convert(amount, from_currency, to_currency, rates=None)`
# - `convert_multi(amount, from_currency, targets)`
# - `record_conversion(...)` and `show_history()`
#
# Then run a short hard-coded demo (do **not** rely on live `input()` so the notebook stays reproducible).

# %%
# TODO: implement convert, convert_multi, record_conversion, show_history

def convert(amount, from_currency, to_currency, rates=None):
    # YOUR CODE HERE
    pass

def convert_multi(amount, from_currency, targets):
    # YOUR CODE HERE
    pass

def record_conversion(amount, from_c, to_c, result):
    # YOUR CODE HERE
    pass

def show_history():
    # YOUR CODE HERE
    pass

# Demo (replace the pass statements first)
print("After implementing, expect something like:")
print("100 USD = 92.00 EUR")
print("250 EUR → several targets")

# %% [markdown]
# ## 3. Alternate Implementation – Dictionary of Lambdas
#
# Write `make_converter(rates)` that returns a dictionary whose keys look like `"USD2EUR"` and whose values are lambdas that perform the conversion.
# Demonstrate a few lookups.

# %%
# TODO: implement make_converter and create ALT_FUNCS

def make_converter(rates):
    # YOUR CODE HERE
    pass

# ALT_FUNCS = make_converter(get_exchange_rates("USD"))
# print a few examples
print("Alternate dict-dispatch ready after implementation.")

# %% [markdown]
# ## 4. More Practice Exercises
#
# 1. Batch-convert a list of USD amounts into EUR.
# 2. Reverse: how many USD are needed for exactly 500 EUR?
# 3. Cross-rate check: USD→EUR→GBP should equal USD→GBP (within floating-point tolerance).
# 4. Tourist budget of 1 000 USD expressed in EUR, GBP, JPY, CRC, CAD.

# %%
# TODO: write the four practice blocks
# Practice 1 – Batch
print("Practice 1 – Batch USD → EUR")
# ...

# Practice 2 – Reverse
print("\nPractice 2 – Reverse")
# ...

# Practice 3 – Cross-rate
print("\nPractice 3 – Cross-rate check")
# ...

# Practice 4 – Tourist budget
print("\nPractice 4 – Tourist budget")
# ...

# %% [markdown]
# ## 5. Simulation Section – Modify Parameters & Observe Results
#
# Implement `run_currency_simulation(...)` that:
#
# - draws `n_sims` noisy rates around the true rate (relative noise `noise_pct`),
# - converts a fixed `base_amount`,
# - draws a 2×2 grid of histograms for the chosen targets,
# - prints mean / std / true value for each target.
#
# Then call it with the defaults and once more with a larger noise percentage.

# %%
# TODO: implement run_currency_simulation

def run_currency_simulation(
    base_amount=100.0,
    from_cur="USD",
    targets=None,
    n_sims=800,
    noise_pct=0.03,
    seed=42,
):
    # YOUR CODE HERE
    pass

print("Simulation function defined – implement and call it.")
# _ = run_currency_simulation()
# _ = run_currency_simulation(noise_pct=0.08, seed=7)

# %% [markdown]
# ## 6. Checklist before comparing with Solution
#
# - [ ] Offline rates load and convert correctly
# - [ ] Multi-target conversion works
# - [ ] History records each conversion
# - [ ] Lambda dictionary produces identical numbers
# - [ ] Simulation produces four histograms and summary stats
# - [ ] Changing `noise_pct` visibly widens the distributions
#
# When finished, open **Currency_Converter_Solution.ipynb** to compare.
