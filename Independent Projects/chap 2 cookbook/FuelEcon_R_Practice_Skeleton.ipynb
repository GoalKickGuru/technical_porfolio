# %% [markdown]
# # FuelEcon_R — Practice Skeleton
#
# **Short name:** `FuelEcon_R` (GitHub-friendly; avoid the long “Driving Visual Analysis with Automobile Data” title).
#
# **Goal:** Follow the *Practical Data Science Cookbook* Ch. 2 pipeline in **R**: import EPA fuel-economy data, explore it, wrangle types, then use **split–apply–combine** + **ggplot2** to explain how combined MPG changed from 1984 onward — and why an “all cars” line can mislead.
#
# **Dataset:** `data/vehicles.csv` (DOE / EPA fueleconomy.gov extract).
# This file is *newer* than the book’s 2013 snapshot (~34k rows, 1984–2014). Expect **~50k rows, 1984–2027, 84 columns**. Numbers will not match the book exactly; the *procedure* does.
#
# **Packages:** `ggplot2`, `dplyr` (modern stand-in for `plyr::ddply`), optional `tidyr`, `readr`.
#
# **Audience (from attached PDFs):**
# - **Expert / analyst** — wants methods, type pitfalls, facet charts.
# - **Technician / fleet ops** — wants Auto vs Manual and displacement.
# - **Executive** — wants the headline: *all-fleet MPG jumped because of EVs; gasoline-only is slower*.
# - **Nonspecialist** — bars, lines, one sentence on “smaller engines + later tech”.
#
# **Flowchart of desired outcome**
#
# ![Flowchart](fuelecon_r_flowchart.png)
#
# Work top-to-bottom. Replace `# YOUR CODE HERE`. Open `FuelEcon_R_Solution.ipynb` only after you attempt a block.

# %% [markdown]
# ## 0. Setup
#
# Load ggplot2 + dplyr. Prefer `readr::read_csv` **or** base `read.csv(..., stringsAsFactors = FALSE)` as in the book.

# %%
# YOUR CODE HERE
# library(ggplot2)
# library(dplyr)
# library(tidyr)
# library(readr)
# theme_set(theme_minimal())

# %% [markdown]
# ## 1. Import vehicles.csv
#
# ### Task 1–3
# 1. Read `data/vehicles.csv` into `vehicles`. Force character columns to stay character (book: `stringsAsFactors = FALSE`).
# 2. Print `head(vehicles)` (or `glimpse`).
# 3. Record `nrow`, `ncol`, and a few `names(vehicles)`.

# %%
# Task 1: import
vehicles <- # YOUR CODE HERE

# Task 2–3: inspect
# YOUR CODE HERE

# %% [markdown]
# ## 2. Explore years and fuel types
#
# ### Task 4–7
# 4. How many unique `year` values? What are `min(year)` and `max(year)`?
# 5. `table(vehicles$fuelType1)` — which primary fuel dominates?
# 6. Cross-tab a charger flag with year, book-style: `with(vehicles, table(sCharger, year))` (or dplyr `count`).
# 7. Compare `class(sCharger)` vs `class(tCharger)` and `unique()` of each. The book’s 2013 file read `T` as logical `TRUE`. Does *this* extract still do that?

# %%
# Task 4
# YOUR CODE HERE

# Task 5
# YOUR CODE HERE

# Task 6
# YOUR CODE HERE

# Task 7 — type pitfall
# YOUR CODE HERE

# %% [markdown]
# ## 3. Transmission cleanup (`trany` → `trany2`)
#
# ### Task 8–10
# 8. Blank `trany` → `NA`.
# 9. First four characters `"Auto"` → `trany2 = "Auto"`, else `"Manual"` (`substr` + `ifelse` as in the book).
# 10. `table(trany2)`. About what Auto:Manual ratio do you see?

# %%
# Tasks 8–10
# YOUR CODE HERE
# vehicles$trany[vehicles$trany == ""] <- NA
# vehicles$trany2 <- ifelse(substr(vehicles$trany, 1, 4) == "Auto", "Auto", "Manual")

# %% [markdown]
# ## 4. Average MPG over time — *all* vehicles
#
# Book recipe: split by `year`, mean of `comb08` / `highway08` / `city08`.
#
# ### Task 11–12
# 11. Build `mpgByYr` with **either** `plyr::ddply` **or** `dplyr::group_by` + `summarise`.
# 12. `ggplot(mpgByYr, aes(year, avgMPG)) + geom_point() + geom_smooth()` plus labels.
#
# **Question:** Does the late-period spike look “too good”? What else entered the fleet after ~2011?

# %%
# Tasks 11–12
mpgByYr <- # YOUR CODE HERE

# ggplot(...)
# YOUR CODE HERE

# %% [markdown]
# ## 5. Gasoline-only subset
#
# Hybrids, plug-ins, and EVs inflate the all-car mean.
#
# ### Task 13–15
# 13. `gasCars`: `fuelType1` in Regular / Premium / Midgrade Gasoline, empty/`NA` `fuelType2`, and `atvType` not Hybrid / Plug-in Hybrid / EV.
# 14. Repeat the year-mean MPG plot on `gasCars` (`mpgByYr_Gas`).
# 15. Compare the two plots in one sentence.

# %%
# Tasks 13–15
gasCars <- # YOUR CODE HERE

mpgByYr_Gas <- # YOUR CODE HERE

# ggplot(...)
# YOUR CODE HERE

# %% [markdown]
# ## 6. Displacement vs MPG, and engine size over time
#
# ### Task 16–19
# 16. Ensure `displ` is numeric (`as.numeric`).
# 17. Scatter `displ` vs `comb08` + `geom_smooth()`. Direction of the relationship?
# 18. Year-mean `avgDispl`. Did engines get smaller after 2008?
# 19. Combine `avgMPG` and `avgDispl` by year, **melt / pivot_longer**, `facet_wrap(~variable, scales = "free_y")`.

# %%
# Tasks 16–19
# YOUR CODE HERE

# %% [markdown]
# ## 7. Four-cylinder gasoline cars
#
# ### Task 20–22
# 20. `gasCars4 <- subset(gasCars, cylinders == 4)` (or `filter`).
# 21. Boxplots of `comb08` by `factor(year)`, faceted by `trany2`.
# 22. Filled bars: `geom_bar(position = "fill")` of Auto vs Manual by year + dashed `y = 0.5` line.

# %%
# Tasks 20–22
gasCars4 <- # YOUR CODE HERE

# boxplot
# YOUR CODE HERE

# filled proportion bar
# YOUR CODE HERE

# %% [markdown]
# ## 8. Makes and models
#
# ### Task 23–26
# 23. Unique 4-cyl *makes* per year (`length(unique(make))`).
# 24. Book trick: list of unique makes per year, then **`Reduce(intersect, ...)`** for makes present *every* year 1984–2014 (the book window). How many? Which?
# 25. Filter to those common makes; year×make mean `comb08`.
# 26. `geom_line()` + `facet_wrap(~make, nrow = 3)`.

# %%
# Tasks 23–26
# YOUR CODE HERE
# uniqMakes <- split(...) or dplyr group_map / plyr::dlply
# commonMakes <- Reduce(intersect, uniqMakes)

# %% [markdown]
# ## Alternate code (same results)
#
# Re-do **one** of: year-mean MPG, the melt/facet chart, or common-makes using a *different* stack.
#
# Ideas:
# - `plyr::ddply` ↔ `dplyr::summarise`
# - `reshape2::melt` ↔ `tidyr::pivot_longer`
# - `subset()` ↔ `dplyr::filter`
# - base `aggregate()` / `tapply()` instead of plyr
# - `ggplot` `stat_summary` on raw rows instead of a pre-aggregated frame

# %%
# YOUR CODE HERE — pick one alternate

# %% [markdown]
# ## More practice
#
# 1. Repeat the gasoline-only year-mean using **city08** and **highway08** on the same faceted chart.
# 2. Violin (or ridgeline if you have ggridges) of `comb08` for 4-cyl cars in 1990 vs 2010 vs 2024.
# 3. Which `VClass` gained the most mean combined MPG between 2008 and 2024? (`group_by(year, VClass)`).
# 4. Supercharger vs turbo: among gasoline cars, compare mean `comb08` for `sCharger == "S"` vs turbo flagged vs neither.
# 5. Restrict to 1984–2014 only and rebuild `mpgByYr_Gas`. How close are you to the book’s story?

# %%
# YOUR CODE HERE — at least two practice items

# %% [markdown]
# ## Simulation / what-if
#
# Change a few knobs and watch the *all-cars* vs *gasoline-only* gap move.
#
# Suggested knobs (edit and re-run):
# - `year_max` — drop model years after this cut
# - `include_hybrids` — TRUE/FALSE
# - `noise_sd` — add Gaussian noise to `comb08` (measurement error)
# - `sample_frac` — subsample rows
#
# Record: (a) latest-year mean MPG all vs gas, (b) year when gasoline mean first exceeds 21 MPG.

# %%
# Interactive knobs
year_max <- 2024          # try 2014, 2018, 2024, 2027
include_hybrids <- FALSE  # try TRUE
noise_sd <- 0             # try 1.5
sample_frac <- 1.0        # try 0.25
set.seed(42)

# YOUR CODE HERE
# 1. optionally sample rows
# 2. optionally add rnorm noise to comb08
# 3. filter year <= year_max
# 4. build all-cars and gasoline-only year means
# 5. plot both series (color = series)

# %% [markdown]
# ## Audience rewrite (do not skip)
#
# Write **four short paragraphs** (4–6 sentences each) of the *same* finding — “all-fleet MPG rose sharply after 2011; gasoline-only rose later and less” — aimed at:
#
# 1. Energy / data analyst (methods + caveats)
# 2. Fleet operations technician (what to spec next)
# 3. Executive / policy desk (one decision)
# 4. Nonspecialist (no jargon)
#
# Use the attached audience PDFs: data literacy, subject knowledge, experts / technicians / executives / nonspecialists.

# %%
# Paste your four paragraphs as comments, or print them with cat()
# YOUR TEXT HERE

# %% [markdown]
# ## Next
#
# - Open **FuelEcon_R_Solution.ipynb** to compare.
# - Keep **FuelEcon_R_Cheatsheet.docx** beside this notebook.
# - Re-use the pipeline on another product-line file with **FuelEcon_R_Reusable_Template.ipynb**.
