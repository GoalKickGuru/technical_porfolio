# %% [markdown]
# # Solution: Linear Regression for Employment Campaigns
#
# **Main application:** Campaign spend → job placements (workforce development / employment services ROI).
# **Secondary:** Training weeks → employment rate.
#
# **Methods:** From-scratch gradient descent (centered), scikit-learn, closed-form OLS, residual diagnostics, Monte-Carlo sensitivity.
#
# ---
#
# ## Project Flowchart
#
# ![Flowchart](employment_campaigns_lr_flowchart.png)
#
# ### Audience adaptation (Employment / Workforce)
# - Technical / labor-economist readers → gradients, residual structure, estimator comparison.
# - HR / workforce executives → marginal placements per $1k + R² in one sentence.
# - Training / policy audience → percentage-point gain per training week.
# - Non-specialists → rising scatter line only.

# %% [markdown]
# ## 0. Setup & Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
np.random.seed(42)

# %% [markdown]
# ## 1. Load & Explore Campaign Spend → Placements

# %%
df = pd.read_csv('data/employment_campaigns.csv')
print('Shape:', df.shape)
display(df.head())
display(df.describe().round(2))

plt.figure(figsize=(7,5))
plt.scatter(df['campaign_spend'], df['placements'], alpha=0.55, edgecolor='k', linewidth=0.3, c='#1A5276')
plt.xlabel('Campaign spend ($000)')
plt.ylabel('Job placements')
plt.title('Employment Campaigns: Spend → Placements (n=200)')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 2. Points and Lines — Manual Prediction (warm-up)

# %%
months = list(range(1, 9))
spend = [15, 22, 28, 35, 42, 48, 55, 62]
placements_obs = [28, 40, 48, 60, 72, 80, 95, 105]

m, b = 1.5, 8
y_pred = [m * x + b for x in spend]

plt.figure(figsize=(7,4))
plt.plot(spend, placements_obs, 'o', label='Observed placements')
plt.plot(spend, y_pred, '-', label=f'Manual line (m={m}, b={b})')
plt.xlabel('Campaign spend ($000)'); plt.ylabel('Placements')
plt.title('Monthly Campaign Spend → Placements — Manual Line')
plt.legend(); plt.tight_layout(); plt.show()

print(f'Implied marginal placements per $1k spend: {m}')

# %% [markdown]
# ## 3. Loss — Sum of Squared Errors

# %%
x = [10, 25, 40]
y = [25, 45, 70]
m1, b1 = 1.2, 12
m2, b2 = 1.5, 5

y_pred1 = [m1*xi + b1 for xi in x]
y_pred2 = [m2*xi + b2 for xi in x]

total_loss1 = sum((yi - yh)**2 for yi, yh in zip(y, y_pred1))
total_loss2 = sum((yi - yh)**2 for yi, yh in zip(y, y_pred2))
print('Loss1:', total_loss1, 'Loss2:', total_loss2)
better_fit = 1 if total_loss1 < total_loss2 else 2
print('Better fit: line', better_fit)

print('Vectorised:', np.sum((np.array(y)-np.array(y_pred1))**2),
      np.sum((np.array(y)-np.array(y_pred2))**2))

# %% [markdown]
# ## 4–5. Gradients for Intercept and Slope

# %%
def get_gradient_at_b(x, y, m, b):
    N = len(x)
    diff = sum(y[i] - (m*x[i] + b) for i in range(N))
    return -2.0 / N * diff

def get_gradient_at_m(x, y, m, b):
    N = len(x)
    diff = sum(x[i] * (y[i] - (m*x[i] + b)) for i in range(N))
    return -2.0 / N * diff

def get_gradient_at_b_vec(x, y, m, b):
    return -2.0 * np.mean(y - (m*x + b))

def get_gradient_at_m_vec(x, y, m, b):
    return -2.0 * np.mean(x * (y - (m*x + b)))

print('Loop  gb:', get_gradient_at_b([10,25,40],[25,45,70],1.2,12))
print('Vec   gb:', get_gradient_at_b_vec(np.array([10.,25,40]), np.array([25.,45,70]), 1.2, 12))

# %% [markdown]
# ## 6. One Gradient Step

# %%
def step_gradient(x, y, b_current, m_current, learning_rate):
    b_grad = get_gradient_at_b(x, y, m_current, b_current)
    m_grad = get_gradient_at_m(x, y, m_current, b_current)
    b = b_current - learning_rate * b_grad
    m = m_current - learning_rate * m_grad
    return [b, m]

print('One step from (0,0):', step_gradient([10,25,40], [25,45,70], 0, 0, 0.001))

# %% [markdown]
# ## 7. Full Gradient Descent Loop

# %%
def gradient_descent(x, y, learning_rate, num_iterations, return_history=False):
    b, m = 0.0, 0.0
    history = []
    x = list(x) if not isinstance(x, list) else x
    y = list(y) if not isinstance(y, list) else y
    for _ in range(num_iterations):
        b, m = step_gradient(x, y, b, m, learning_rate)
        if return_history:
            yhat = [m*xi + b for xi in x]
            loss = sum((yi-yh)**2 for yi,yh in zip(y,yhat)) / len(y)
            history.append((b, m, loss))
    if return_history:
        return [b, m], history
    return [b, m]

b_q, m_q = gradient_descent(spend, placements_obs, 0.0005, 3000)
print(f'Monthly series GD → m={m_q:.3f}, b={b_q:.2f}')

# %% [markdown]
# ## 8. From-Scratch GD on Campaign Spend → Placements (centered)

# %%
X = df['campaign_spend'].values.astype(float)
y = df['placements'].values.astype(float)

Xc = X - X.mean()
yc = y - y.mean()

(b_c, m_c), hist = gradient_descent(Xc.tolist(), yc.tolist(),
                                    learning_rate=0.0005,
                                    num_iterations=2500,
                                    return_history=True)
m_gd = m_c
b_gd = y.mean() - m_gd * X.mean()
print(f'Centered GD → m={m_gd:.4f}, b={b_gd:.2f}')
print(f'Marginal placements per $1k campaign spend: {m_gd:.2f}')

yhat_gd = m_gd * X + b_gd
mse_gd = np.mean((y - yhat_gd)**2)
ss_tot = np.sum((y - y.mean())**2)
r2_gd = 1 - np.sum((y - yhat_gd)**2) / ss_tot
print(f'MSE={mse_gd:.1f}, R²={r2_gd:.4f}')

plt.figure(figsize=(7,5))
plt.scatter(X, y, alpha=0.55, edgecolor='k', linewidth=0.3, c='#1A5276', label='Data')
xx = np.linspace(X.min()-2, X.max()+2, 100)
plt.plot(xx, m_gd*xx + b_gd, 'r-', lw=2.2, label=f'GD: placements={m_gd:.2f}·spend+{b_gd:.1f}')
plt.xlabel('Campaign spend ($000)'); plt.ylabel('Job placements')
plt.title('From-Scratch Gradient Descent Fit')
plt.legend(); plt.tight_layout(); plt.show()

losses = [h[2] for h in hist]
plt.figure(figsize=(6,3.5))
plt.plot(losses); plt.yscale('log')
plt.xlabel('Iteration'); plt.ylabel('MSE (centered)')
plt.title('Convergence of Centered GD'); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 9. scikit-learn LinearRegression

# %%
X_2d = X.reshape(-1, 1)
model = LinearRegression().fit(X_2d, y)
m_sk, b_sk = model.coef_[0], model.intercept_
r2_sk = model.score(X_2d, y)
print(f'sklearn → m={m_sk:.4f}, b={b_sk:.2f}, R²={r2_sk:.4f}')

yhat_sk = model.predict(X_2d)

plt.figure(figsize=(7,5))
plt.scatter(X, y, alpha=0.55, edgecolor='k', linewidth=0.3, c='#1A5276', label='Data')
plt.plot(xx, m_sk*xx + b_sk, 'g-', lw=2.2, label=f'sklearn: placements={m_sk:.2f}·spend+{b_sk:.1f}')
plt.xlabel('Campaign spend ($000)'); plt.ylabel('Job placements')
plt.title('scikit-learn LinearRegression Fit')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 10. More Practice — Closed Form, Residuals, Training → Employment Rate

# %%
# Closed-form OLS
x_bar, y_bar = X.mean(), y.mean()
m_cf = np.sum((X - x_bar)*(y - y_bar)) / np.sum((X - x_bar)**2)
b_cf = y_bar - m_cf * x_bar
print(f'Closed-form → m={m_cf:.4f}, b={b_cf:.2f}')

comparison = pd.DataFrame({
    'Method': ['Centered GD', 'sklearn', 'Closed-form'],
    'Slope m (placements per $1k)': [m_gd, m_sk, m_cf],
    'Intercept b': [b_gd, b_sk, b_cf]
})
display(comparison.round(4))

# Residual diagnostics
resid = y - yhat_sk
fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
axes[0].scatter(yhat_sk, resid, alpha=0.55, edgecolor='k', linewidth=0.3, c='#1A5276')
axes[0].axhline(0, color='r', ls='--')
axes[0].set_xlabel('Fitted placements'); axes[0].set_ylabel('Residual')
axes[0].set_title('Residuals vs Fitted')
axes[1].hist(resid, bins=20, edgecolor='k', alpha=0.75, color='#1A5276')
axes[1].set_xlabel('Residual'); axes[1].set_title('Residual Distribution')
plt.suptitle(f'Residual Analysis (R² = {r2_sk:.3f})')
plt.tight_layout(); plt.show()
print('Residual mean ≈ 0?', round(resid.mean(), 6))

# --- Training weeks → employment rate ---
train = pd.read_csv('data/employment_training.csv')
W = train['training_weeks'].values
E = train['employment_rate'].values
tr_model = LinearRegression().fit(W.reshape(-1,1), E)
slope_tr = tr_model.coef_[0]
int_tr = tr_model.intercept_
r2_tr = tr_model.score(W.reshape(-1,1), E)
print(f'\nTraining model: employment_rate = {int_tr:.3f} + {slope_tr:.4f}·training_weeks')
print(f'Slope ≈ {slope_tr*100:.1f} percentage points per extra week of training  |  R² = {r2_tr:.3f}')
print('Workforce reading: each additional week of training is associated with about {:.1f} pp higher employment rate.'.format(slope_tr*100))

plt.figure(figsize=(7,4.5))
plt.scatter(W, E, alpha=0.6, edgecolor='k', linewidth=0.3, c='#1E8449')
xxw = np.linspace(W.min(), W.max(), 80)
plt.plot(xxw, int_tr + slope_tr*xxw, 'r-', lw=2, label=f'rate = {int_tr:.2f} + {slope_tr:.3f}·weeks')
plt.xlabel('Training weeks'); plt.ylabel('Employment rate')
plt.title('Training Intensity → Employment Rate')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 11. Simulation — Learning Rate, Noise & Sample Size

# %%
# === TUNABLE PARAMETERS ===
LEARNING_RATE = 0.0005
N_ITER        = 2500
NOISE_STD     = 0.0
SAMPLE_FRAC   = 1.0
N_REPS        = 30
# ===========================

def run_one(X, y, alpha, n_iter, noise_std, sample_frac):
    n = len(X)
    idx = np.random.choice(n, size=max(20, int(n*sample_frac)), replace=False)
    Xs, ys = X[idx], y[idx].copy()
    if noise_std > 0:
        ys = ys + np.random.normal(0, noise_std, size=len(ys))
    Xc, yc = Xs - Xs.mean(), ys - ys.mean()
    b_c, m_c = gradient_descent(Xc.tolist(), yc.tolist(), alpha, n_iter)
    m = m_c
    b = ys.mean() - m * Xs.mean()
    yhat = m*Xs + b
    r2 = 1 - np.sum((ys-yhat)**2) / np.sum((ys-ys.mean())**2)
    return m, b, r2

ms, bs, r2s = [], [], []
for _ in range(N_REPS):
    m, b, r2 = run_one(X, y, LEARNING_RATE, N_ITER, NOISE_STD, SAMPLE_FRAC)
    ms.append(m); bs.append(b); r2s.append(r2)

print(f'Settings: α={LEARNING_RATE}, iters={N_ITER}, noise={NOISE_STD}, frac={SAMPLE_FRAC}')
print(f'Slope (placements per $1k) mean±std : {np.mean(ms):.4f} ± {np.std(ms):.4f}')
print(f'Intercept                  mean±std : {np.mean(bs):.2f} ± {np.std(bs):.2f}')
print(f'R²                         mean±std : {np.mean(r2s):.4f} ± {np.std(r2s):.4f}')

fig, axes = plt.subplots(1, 3, figsize=(12, 3.8))
axes[0].hist(ms, bins=12, edgecolor='k', alpha=0.75, color='#1A5276')
axes[0].axvline(m_sk, color='r', ls='--', label='sklearn'); axes[0].legend(fontsize=8)
axes[0].set_title('Slope (placements per $1k)')
axes[1].hist(bs, bins=12, edgecolor='k', alpha=0.75, color='#1A5276')
axes[1].axvline(b_sk, color='r', ls='--'); axes[1].set_title('Intercept')
axes[2].hist(r2s, bins=12, edgecolor='k', alpha=0.75, color='#1A5276')
axes[2].axvline(r2_sk, color='r', ls='--'); axes[2].set_title('R²')
plt.suptitle('Monte-Carlo Sensitivity — Campaign Spend → Placements')
plt.tight_layout(); plt.show()

# %% [markdown]
# ### Extra: learning-rate effect on loss trajectory

# %%
def loss_trajectory(X, y, alpha, n_iter=2000):
    Xc, yc = X - X.mean(), y - y.mean()
    b, m = 0.0, 0.0
    losses = []
    for _ in range(n_iter):
        b, m = step_gradient(Xc.tolist(), yc.tolist(), b, m, alpha)
        err = yc - (m*Xc + b)
        losses.append(np.mean(err**2))
    return losses

plt.figure(figsize=(8,4))
for alpha in [1e-5, 5e-5, 1e-4, 5e-4, 0.001]:
    losses = loss_trajectory(X, y, alpha)
    plt.plot(losses, label=f'α={alpha}')
plt.yscale('log'); plt.xlabel('Iteration'); plt.ylabel('MSE (centered)')
plt.title('Learning-Rate Effect — Employment Campaign GD')
plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Cheat Sheet
#
# | Concept | Formula / Code | Workforce reading |
# |---------|----------------|-------------------|
# | Line | `yhat = m*x + b` | Predicted placements or employment rate |
# | Slope `m` | marginal effect | Extra placements per $1k spend; or pp per training week |
# | Intercept `b` | baseline | Use cautiously outside observed range |
# | SSE / MSE | `sum((y-yhat)**2)` / mean | Total / average squared prediction error |
# | Gradient b / m | `−2/N · Σ …` | Direction of steepest ascent of loss |
# | Update | `param -= α * gradient` | Step downhill on the loss surface |
# | Convergence | params almost stop changing | Approximate minimum of loss reached |
# | sklearn | `LinearRegression().fit` | Fast reference OLS |
# | Closed form | `m = cov(x,y)/var(x)` | Exact simple-OLS solution |
# | Centering | GD on demeaned data | Numerically stable when scales differ |
#
# **Key results (campaign spend → placements)**
# - Marginal placements ≈ **1.11 per $1k campaign spend**
# - Intercept ≈ **16.7**
# - R² ≈ **0.59**
# - GD, sklearn and closed-form agree closely when learning rate and iterations are sensible.
#
# **Training practice**
# - ≈ **4.4 percentage points** higher employment rate per extra week of training.
