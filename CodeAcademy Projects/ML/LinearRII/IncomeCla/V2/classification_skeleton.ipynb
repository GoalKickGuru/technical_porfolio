# %% [markdown]
# # Income Classification — Practice Skeleton
#
# Complete each cell where you see `# TODO`. Refer to the project instructions for guidance.
#
# **Dataset**: 1994 U.S. Census — predict whether income exceeds $50K/year.

# %% [markdown]
# ## Step 0 — Imports

# %%
# TODO: Import pandas, numpy, matplotlib, seaborn, and all sklearn modules you'll need
# Hint: train_test_split, LogisticRegression, confusion_matrix, accuracy_score,
#       precision_score, recall_score, f1_score, roc_curve, roc_auc_score, StandardScaler

# %% [markdown]
# ## Step 1 — Load Data & Check Class Imbalance

# %%
# TODO: Define column names, load 'adult.data' into df
# TODO: Strip whitespace from all object-type columns
# TODO: Print value_counts(normalize=True) for income

# %% [markdown]
# ## Step 2 — Create Feature Matrix X (with Dummy Variables)

# %%
# TODO: Define feature_cols (at minimum: age, capital-gain, capital-loss,
#       hours-per-week, sex, race, education)
# TODO: Use pd.get_dummies(..., drop_first=True) to create X

# %% [markdown]
# ## Step 3 — Correlation Heatmap

# %%
# TODO: Create a seaborn heatmap of X.corr()

# %% [markdown]
# ## Step 4 — Create Binary Output Variable y

# %%
# TODO: Use np.where to create y: 0 when income == '<=50K', else 1

# %% [markdown]
# ## Step 5 — Train/Test Split & Fit Logistic Regression

# %%
# TODO: Split with random_state=1, test_size=0.2
# TODO: Create LogisticRegression(C=0.05, penalty='l1', solver='liblinear')
# TODO: Fit on train, predict on test → save as y_pred

# %% [markdown]
# ## Step 6 — Print Model Parameters

# %%
# TODO: Print intercept and coefficients

# %% [markdown]
# ## Step 7 — Confusion Matrix & Accuracy

# %%
# TODO: Print confusion_matrix(y_test, y_pred)
# TODO: Print accuracy score using .score()

# %% [markdown]
# ## Step 8 — Coefficient DataFrame

# %%
# TODO: Create DataFrame with columns ['var', 'coef']
#       using zip(x_train.columns, log_reg.coef_[0])
# TODO: Filter out zero coefficients, sort by 'coef'

# %% [markdown]
# ## Step 9 — Barplot of Coefficients

# %%
# TODO: sns.barplot(data=coef_df, x='var', y='coef')
#       Rotate x-labels 90 degrees

# %% [markdown]
# ## Step 10 — ROC Curve & AUC

# %%
# TODO: Get predicted probabilities with .predict_proba()
# TODO: Calculate roc_auc_score
# TODO: Plot ROC curve using roc_curve(), include diagonal reference line

# %% [markdown]
# ## Bonus — Your Own Extensions
#
# - Try adding `workclass` or `marital-status` as features. Does AUC improve?
# - Experiment with different C values (0.01, 0.1, 1.0). How does sparsity change?
# - Compare L1 vs L2 penalty. Which produces fewer non-zero coefficients?
