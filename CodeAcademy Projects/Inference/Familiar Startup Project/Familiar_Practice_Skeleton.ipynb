# %% [markdown]
# # Familiar: Blood Transfusion Pack Analysis — Practice Skeleton
#
# **Goal:** Help the Familiar startup decide whether its Vein Pack and Artery Pack deliver meaningful benefits (longer lifespan) and whether they differ in side-effect profiles (iron levels).
#
# You will practice the classic statistical workflow:
#
# 1. Exploratory data analysis
# 2. One-sample t-test (Vein vs. 73 years)
# 3. Two-sample t-test (Vein vs. Artery)
# 4. Chi-square test of association (Pack × Iron)
# 5. Effect sizes, confidence intervals, assumption checks
# 6. Bootstrap / Monte-Carlo simulation for robustness
#
# Work through every **TODO**.  When you are stuck, open the companion **Solution** notebook.
#
# Data files (already in the working directory):
#
# - `familiar_lifespan.csv` – 40 subscribers, pack type + lifespan
# - `familiar_iron.csv` – 345 subscribers, pack type + iron category (low / normal / high)

# %% [markdown]
# ## Flowchart: Desired Outcome for the Familiar Analysis
#
# This flowchart captures the full recommended process for turning the two CSV files into actionable product insights for Familiar.
# It emphasises **exploratory checks → formal hypothesis tests → practical effect sizes → audience-tailored reporting**.
#
# ```mermaid
# flowchart TD
#     A[Start: Business Questions<br/>• Does Vein Pack extend life beyond 73 yrs?<br/>• Is Artery Pack different from Vein?<br/>• Do packs affect iron levels?] --> B[Load & Inspect Data<br/>familiar_lifespan.csv<br/>familiar_iron.csv]
#     B --> C[Exploratory Analysis<br/>head, describe, value_counts<br/>boxplots / histograms]
#     C --> D1[One-Sample t-test<br/>Vein vs μ₀ = 73]
#     C --> D2[Two-Sample t-test<br/>Vein vs Artery]
#     C --> D3[Chi-Square Test<br/>Pack × Iron Level]
#     D1 --> E{ p &lt; 0.05 ? }
#     D2 --> E
#     D3 --> E
#     E -->|Yes| F[Compute Effect Sizes<br/>Cohen's d, Cramer's V<br/>95 % Confidence Intervals]
#     E -->|No / Borderline| G[Check Assumptions<br/>Normality Shapiro-Wilk<br/>Equal variance Levene<br/>Retrospective power]
#     F --> H[Visualize for Stakeholders<br/>Annotated boxplots<br/>Stacked bar for iron]
#     G --> H
#     H --> I[Bootstrap / Simulation<br/>Resample means &amp; differences<br/>Sensitivity to α or N]
#     I --> J[Prepare Audience-Tailored Report<br/>• Executives: headline + ROI / risk<br/>• Technical: methods + diagnostics<br/>• Mixed: layered sections + appendix]
#     J --> K[Decision &amp; Next Steps<br/>Marketing claims, pack recommendations,<br/>further data collection]
#     style E fill:#fff3cd,stroke:#856404
#     style J fill:#e6f3ff,stroke:#0066cc
#     style I fill:#e8f5e9,stroke:#2e7d32
# ```
#
# **Key takeaway (from the supplied PDFs):** The final reporting box is critical.
# A C-level reader has little time and moderate data literacy; a data-science peer wants full methods and diagnostics.
# Structure the deliverable so each audience can “swoop in” for the level of detail they need (Introduction → Body → Appendix).

# %% [markdown]
# ## Audience Considerations (from the provided PDFs)
#
# Before you write a single line of the final report, answer three questions about the people who will read it:
#
# 1. **Data Literacy** (Jočys – “What to Consider When Considering the Audience”)
#    - Highly data-literate readers (engineers, data scientists, some psychologists) can handle scatterplots, boxplots, confidence intervals and linear models.
#    - Less data-literate readers (literature, fine arts, many executives) need simpler bars, lines and dots; avoid jargon or explain it with friendly metaphors (“a friendly robot sipping warm oil”).
#
# 2. **Subject Knowledge & Audience Type** (McMurrey – “Audience and Situation Analysis”)
#    - **Experts / Technicians** – know the product theory or operations; want technical depth.
#    - **Executives** – make business / marketing decisions; have little technical knowledge; need the “so-what” and risk.
#    - **Nonspecialists** – potential subscribers or board members; want clear practical implications.
#    - Mixed audiences are common → use clear headings and section introductions so each group can skip what they do not need.
#
# 3. **Report Structure for Multiple Audiences** (paper-structure.pdf)
#    - **Primary collaborator / client** – reads Introduction + Conclusion, skims Body.
#    - **Executive** – only the headlines in Introduction / Conclusion.
#    - **Technical supervisor** – Body + Appendix for quality control.
#    - Therefore organise: most important findings first, put detailed diagnostics in an Appendix, and leave “signposts” everywhere.
#
# **For Familiar specifically:** Marketing & product leadership are the primary audience (executive + some subject knowledge about blood-transfusion packs).
# Data-science peers and the medical-advisory board form secondary audiences.
# Consequently the notebooks and the 1-page summary emphasise:
#
# - Clear verbal conclusions (“Vein Pack subscribers live significantly longer than 73 years”).
# - Visuals that work for both technical and non-technical readers.
# - A short “Business Implications” paragraph after every statistical result.

# %% [markdown]
# ## 1. Setup – Import libraries & load data
#
# ### TODO
# 1. Import `pandas` as `pd`, `numpy` as `np`.
# 2. From `scipy.stats` import the three tests you will need later (`ttest_1samp`, `ttest_ind`, `chi2_contingency`).
# 3. Load the two CSV files into DataFrames named `lifespans` and `iron`.
# 4. Print the first five rows of each (use `.head()`).

# %%
# TODO: imports
# import ...

# TODO: load data
# lifespans = ...
# iron = ...

# TODO: inspect
# print(...)
# print(...)

# %% [markdown]
# ## 2. Vein Pack – Does it beat the 73-year benchmark?
#
# ### TODO
# 1. Extract the lifespan Series for subscribers whose `pack == 'vein'`.  Store it in `vein_pack_lifespans`.
# 2. Compute and print the mean lifespan with `np.mean()`.  Is it larger than 73?
# 3. Run a **one-sample t-test** against the null value 73.  Print the p-value.
# 4. Using a significance threshold of α = 0.05, state whether the average lifespan is significantly different from 73 years.

# %%
# TODO: extract vein lifespans
# vein_pack_lifespans = ...

# TODO: mean
# print(...)

# TODO: one-sample t-test
# tstat, pval = ...
# print(pval)

# %% [markdown]
# ## 3. Upselling – Vein vs. Artery Pack lifespans
#
# ### TODO
# 1. Extract the lifespan Series for the Artery Pack → `artery_pack_lifespans`.
# 2. Print its mean.  Is it higher or lower than the Vein Pack mean?
# 3. Run a **two-sample (independent) t-test** comparing the two packs.  Print the p-value.
# 4. At α = 0.05, is there a statistically significant difference?

# %%
# TODO: extract artery lifespans
# artery_pack_lifespans = ...

# TODO: mean
# print(...)

# TODO: two-sample t-test
# tstat, pval = ...
# print(pval)

# %% [markdown]
# ## 4. Side Effects – Iron levels by pack
#
# ### TODO
# 1. Print the first five rows of the `iron` DataFrame (if you have not already).
# 2. Build a contingency table of `pack` versus `iron` with `pd.crosstab`.  Save it as `Xtab` and print it.
# 3. Run a **Chi-square test of independence**.  Print the p-value.
# 4. At α = 0.05, is there a significant association between pack type and iron category?

# %%
# TODO: contingency table
# Xtab = ...
# print(Xtab)

# TODO: Chi-square test
# chi2, pval, dof, expected = ...
# print(pval)

# %% [markdown]
# ## 5. Extra Practice – Effect sizes, confidence intervals & assumption checks
#
# These steps go beyond the original brief and give you a richer story for the stakeholders.
#
# ### TODO
# 1. **Cohen’s d** for the Vein-vs-Artery comparison:
#    \( d = \frac{\bar{x}_1 - \bar{x}_2}{s_{pooled}} \)
#    Write a small helper (or use a library) and print the value.  Interpret: |d| ≈ 0.2 small, 0.5 medium, 0.8 large.
# 2. **95 % confidence interval** for the difference of means (Vein − Artery).  You may use the formula or `scipy.stats.ttest_ind` together with the standard error.
# 3. **Normality check** – run Shapiro-Wilk on both lifespan samples (`scipy.stats.shapiro`).
# 4. **Equal-variance check** – Levene’s test (`scipy.stats.levene`).
# 5. **Cramér’s V** for the iron contingency table (effect size for Chi-square).

# %%
# TODO: Cohen's d
# def cohens_d(x, y):
#     ...
# print(cohens_d(vein_pack_lifespans, artery_pack_lifespans))

# TODO: 95 % CI for difference of means
# ...

# TODO: Shapiro-Wilk
# ...

# TODO: Levene
# ...

# TODO: Cramér's V
# ...

# %% [markdown]
# ## 6. Visualizations (audience-friendly)
#
# ### TODO
# 1. Create side-by-side boxplots of lifespan by pack (use `seaborn.boxplot` or pure matplotlib).
# 2. Create a stacked (or grouped) bar chart showing the proportion of low / normal / high iron for each pack.
# 3. Add clear titles, axis labels and a short annotation that a non-technical executive could understand.

# %%
# TODO: boxplots of lifespan
# import matplotlib.pyplot as plt
# import seaborn as sns
# ...

# TODO: iron stacked / grouped bars
# ...

# %% [markdown]
# ## 7. Simulation & Sensitivity Section
#
# Modify a few values and observe how the conclusions change.  This builds intuition about power, sample size and robustness.
#
# ### TODO – Bootstrap the difference of means
# 1. Write a loop (or use `np.random.choice`) that resamples **with replacement** from the two lifespan arrays, computes the difference of means, and stores 2 000 such differences.
# 2. Plot a histogram of the bootstrap distribution.
# 3. Compute the 2.5 % and 97.5 % percentiles → approximate 95 % bootstrap CI.
# 4. What percentage of bootstrap replicates show Vein mean > Artery mean?
#
# ### TODO – Sensitivity to the null value
# - Re-run the one-sample t-test against μ₀ = 74, 75 and 76.  How does the p-value change?
#
# ### TODO – What-if sample size
# - Sub-sample only 10 observations from each pack and re-run the two-sample test.  Does significance disappear?  (Illustrates the importance of adequate N.)

# %%
# TODO: Bootstrap
# np.random.seed(42)
# n_boot = 2000
# diffs = []
# for _ in range(n_boot):
#     ...
# print(np.percentile(diffs, [2.5, 97.5]))
# ...

# TODO: Sensitivity to mu0
# for mu0 in [74, 75, 76]:
#     ...

# TODO: Small-sample experiment
# ...

# %% [markdown]
# ## 8. Alternate Code Paths (same statistical result)
#
# There is rarely only one correct way to obtain a result.  Try at least one of the alternatives below.
#
# ### TODO (choose any)
# - Perform the two-sample t-test with `statsmodels.stats.weightstats.ttest_ind` instead of `scipy`.
# - Compute the one-sample t-statistic **by hand** using the classic formula
#   \( t = \frac{\bar{x} - \mu_0}{s / \sqrt{n}} \) and obtain the two-sided p-value from a t-distribution (`scipy.stats.t.sf`).
# - Build the contingency table with `pd.pivot_table` or `groupby` + `unstack` instead of `crosstab`.
# - Use `pingouin` (if available) for a richer t-test output that includes Cohen’s d automatically.

# %%
# TODO: alternate implementation(s)
# ...

# %% [markdown]
# ## 9. Mini Business Write-up (practice for the 1-page report)
#
# ### TODO
# In a short markdown cell (or as print statements) answer:
#
# 1. **Problem Statement** – one or two sentences.
# 2. **Key statistical findings** (p-values + effect sizes).
# 3. **Business recommendation** for Familiar’s marketing and product teams.
# 4. **Limitations / next data to collect**.

# %%
# TODO: write your summary here (or use a markdown cell)
print("Problem Statement: ...")
print("Findings: ...")
print("Recommendation: ...")
print("Limitations: ...")

# %% [markdown]
# ## End of Practice Skeleton
#
# Compare your answers with the companion **Familiar_Solution.ipynb**.
# Re-run the simulation cells with different seeds or different μ₀ values to deepen your intuition.
