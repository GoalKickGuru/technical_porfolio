# %% [markdown]
# # Life Expectancy By Country — Practice Skeleton
#
# **Goal:** Investigate how a country’s economic success (GDP) relates to average life expectancy across 158 countries. Practice extracting vectors with `dplyr::pull()`, computing quantiles, splitting data by a threshold (median GDP), and comparing distributions with histograms.
#
# **Data:** `data/country_data.csv` — columns include `country`, `life_expectancy`, and `GDP`.
#
# **Audience notes (from the attached PDFs):**
# - **Data-literate / analysts:** comfortable with quartiles, histograms, and precise numeric summaries.
# - **Subject experts (public health / development economists):** skip basic definitions; highlight policy-relevant contrasts.
# - **Executives / nonspecialists:** short attention span — lead with the headline (“Higher-GDP countries live substantially longer”) and one clear visual; avoid jargon.
# - Always match chart complexity and explanation depth to the audience.
#
# **How to use this notebook:**
# 1. Read each markdown step.
# 2. Fill in the code cells marked `# YOUR CODE HERE`.
# 3. Run the cell and compare with the expected behaviour described.
# 4. When stuck, open the companion **Solution** notebook.
# 5. After finishing the core tasks, complete **Alternate Code**, **More Practice**, and **Simulation**.
#
# ---
#
# ## Flowchart of the Desired Outcome
#
# ![Life Expectancy Analysis Flowchart](life_expectancy_flowchart.png)
#
# The flowchart shows the end-to-end pipeline: load → extract life expectancy → quartiles & histogram → extract GDP & median → split into low/high GDP groups → group-wise quartiles & histograms → interpret impact → optional simulation.

# %% [markdown]
# ## Step 0 — Setup & Load Packages
#
# Load the tidyverse packages we need. (If you are in a clean environment you may need to install them first.)

# %%
# load packages
library(ggplot2)
library(readr)
library(dplyr)

# %% [markdown]
# ## Step 1 — Access the Data
#
# We have imported a dataset containing life expectancy in different countries. The data live in the variable named `data`.
#
# - Inspect the first 6 rows with `head()`.
# - Look at the column names. What other pieces of information does this dataset contain?
# - You may want to comment out the `head()` call after looking at the data.

# %%
# import and inspect data
data <- read_csv("data/country_data.csv")

# YOUR CODE HERE: inspect the first rows
# head(data)

# %% [markdown]
# ## Step 2 — Isolate the Life Expectancy Column as a Vector
#
# Many of R’s statistical functions require a **numeric vector**, not a data-frame column.
#
# - Use `dplyr::pull()` (instead of `select()`) to extract the `life_expectancy` column into a vector named `life_expectancy`.
# - Pay attention to capitalization of the column name!

# %%
# life expectancy vector
# YOUR CODE HERE
# life_expectancy <- data %>%
#   pull(life_expectancy)

# %% [markdown]
# ## Step 3 — Find the Quartiles
#
# Use R’s `quantile()` function to find the quartiles of `life_expectancy`.
# Store the result in `life_expectancy_quartiles` and view it.

# %%
# life expectancy quartiles
# YOUR CODE HERE
# life_expectancy_quartiles <- quantile(life_expectancy)
# life_expectancy_quartiles

# %% [markdown]
# ## Step 4 — Plot the Histogram of Life Expectancy
#
# By looking at the three quartile values you get a sense of the spread.
# Plot the histogram with:
#
# ```r
# hist(life_expectancy)
# ```
#
# Does the shape match what you expected from the quartiles?

# %%
# plot histogram of life expectancy
# YOUR CODE HERE
# hist(life_expectancy)

# %% [markdown]
# ## Step 5 — Interpret a Life Expectancy of 70 Years
#
# If a country has a life expectancy of **70 years**, does that fall in the first, second, third, or final quarter of the data?
#
# (Write a short answer in a comment or a new markdown cell after you run the quantiles.)

# %% [markdown]
# ## Step 6 — Isolate the GDP Column
#
# GDP is a measure of a country’s wealth. We will split the data into “low GDP” and “high GDP” countries using the median GDP as the threshold.
#
# Extract the GDP column into a numeric vector named `gdp` (again using `pull()`).

# %%
# gdp vector
# YOUR CODE HERE
# gdp <- data %>%
#   pull(GDP)

# %% [markdown]
# ## Step 7 — Find the Median GDP
#
# You can use `median()` or `quantile(gdp, 0.5)`.
# Store the value in `median_gdp` and print it.

# %%
# median gdp
# YOUR CODE HERE
# median_gdp <- median(gdp)
# median_gdp

# %% [markdown]
# ## Step 8 — Split the Data into Low-GDP and High-GDP Groups
#
# - Create `low_gdp` containing the **life_expectancy** values for countries whose GDP is ≤ the median.
# - Create `high_gdp` containing the **life_expectancy** values for countries whose GDP is > the median.
#
# Hint (you can adapt this pattern):
#
# ```r
# low_gdp <- data %>%
#   filter(GDP <= median_gdp) %>%
#   pull(life_expectancy)
# ```

# %%
# low gdp life expectancy vector
# YOUR CODE HERE

# high gdp life expectancy vector
# YOUR CODE HERE

# %% [markdown]
# ## Step 9 — Quartiles of the Low-GDP Group
#
# Compute the quartiles of `low_gdp` and store them in `low_gdp_quartiles`. View the result.

# %%
# low gdp quartiles
# YOUR CODE HERE
# low_gdp_quartiles <- quantile(low_gdp)
# low_gdp_quartiles

# %% [markdown]
# ## Step 10 — Quartiles of the High-GDP Group
#
# Do the same for the high-GDP countries → `high_gdp_quartiles`.

# %%
# high gdp quartiles
# YOUR CODE HERE
# high_gdp_quartiles <- quantile(high_gdp)
# high_gdp_quartiles

# %% [markdown]
# ## Step 11 — Histograms of the Two Groups
#
# Plot the two histograms side-by-side (or one after the other) using different colours so you can compare the distributions:
#
# ```r
# hist(low_gdp, col = "red", main = "Low GDP Countries")
# hist(high_gdp, col = "blue", main = "High GDP Countries")
# ```

# %%
# plot low gdp histogram
# YOUR CODE HERE

# plot high gdp histogram
# YOUR CODE HERE

# %% [markdown]
# ## Step 12 — Interpret a Life Expectancy of 70 Years Again
#
# Consider a country with life expectancy of **70 years**:
#
# - If the country is in the **top half of GDP**, is 70 years in the 1st, 2nd, 3rd or 4th quarter of that group’s life-expectancy distribution?
# - If the country is in the **bottom half of GDP**, where does 70 years fall?
#
# Write your conclusions in a markdown cell.

# %% [markdown]
# ## Alternate Code Paths
#
# Try at least two of the following alternative approaches that achieve the same results:
#
# 1. Base-R extraction: `data$life_expectancy` or `data[["life_expectancy"]]` instead of `pull()`.
# 2. `quantile(..., probs = c(0.25, 0.5, 0.75))` or `fivenum()` / `summary()`.
# 3. Use `ifelse` or a logical index instead of `filter()` to split the groups.
# 4. `tapply` / `split` / `by` to compute quantiles by a GDP-group factor.
# 5. `ggplot2` histograms instead of base `hist()`.

# %%
# ALTERNATE 1 — base-R column extraction + fivenum
# YOUR CODE HERE

# ALTERNATE 2 — logical indexing split
# YOUR CODE HERE

# %% [markdown]
# ## More Practice
#
# 1. Compute the **IQR** of the overall life expectancy and of each GDP group. Which group is more spread out?
# 2. Calculate the **mean** and **median** for each group. Is the distribution skewed? (mean vs median)
# 3. Add a third group: “middle 50 % of GDP” (between the 25th and 75th percentiles of GDP) and compare its life-expectancy quartiles.
# 4. (Optional) If you add a continent or region column, compute median life expectancy by region with `group_by` + `summarise`.

# %%
# MORE PRACTICE — IQR, mean/median, extra groups
# YOUR CODE HERE

# %% [markdown]
# ## Simulation Section
#
# Modify a few values and observe how the results change.
#
# **Ideas to try:**
#
# - Change the split threshold from the **median** to the **mean**, or to the 40th / 60th percentile of GDP.
# - Add random noise to life expectancy (`life_expectancy + rnorm(n, 0, sd)`) and re-compute the group quartiles.
# - Sub-sample 50 % of the countries and see how stable the quartile differences are.
# - Monte-Carlo: repeat the median-split many times after adding noise; collect the difference in group medians and plot a histogram of that difference.
#
# Write a small parameterised block so you can change `split_prob`, `noise_sd`, or `n_sim` and re-run.

# %%
# SIMULATION — parameterised experiment
# set.seed(123)
# split_prob <- 0.5          # change me (0.4, 0.5, 0.6 ...)
# noise_sd   <- 0            # change me (0, 1, 2 ...)
# n_sim      <- 200          # change me

# YOUR CODE HERE

# %% [markdown]
# ## Key Reflection (Audience Adaptation)
#
# After finishing the analysis, write two short paragraphs:
#
# 1. **For a data analyst / technical colleague** — precise numbers, quartile values, possible next steps (correlation, regression, controls).
# 2. **For a busy executive or policy maker** — one headline finding, one supporting visual description, and one concrete implication.
#
# Keep the language appropriate to each audience’s data literacy and time span (see the attached audience PDFs).
