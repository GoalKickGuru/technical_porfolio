# %% [markdown]
# # Bayesian Hypothesis Testing Approaches
# ## Full Extended Project — Practice Skeleton
#
# Work through each section. Replace every `# TODO` with working code.
# Consult the Solution notebook only after you have attempted the exercise.
#
# **Required files**
# - `data/familiar_lifespan.csv`
# - `bayesian_ht_flowchart.png` (already provided)

# %% [markdown]
# ## Flowchart
#
# ![Bayesian HT Flowchart](bayesian_ht_flowchart.png)
#
# Study the flowchart — it is the roadmap for the whole notebook.

# %% [markdown]
# ## Audience reminder
# Bayesian results are usually reported as probabilities. Before you code, decide how you would phrase the final claim for:
#
# 1. an executive (one sentence)
# 2. a product manager (actionable)
# 3. a statistical reviewer (full posterior + sensitivity)

# %% [markdown]
# ## 0. Setup

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

rng = np.random.default_rng(42)

# TODO: load data/familiar_lifespan.csv
# TODO: create numeric arrays vein and artery
# TODO: print n, mean, sd for each pack

# %% [markdown]
# ## 1. Frequentist vs Bayesian contrast
# Write (in a markdown cell or comments) the Bayesian answers to the two Familiar questions that the frequentist project answered with p-values.

# %% [markdown]
# ## 2. Beta-Binomial A/B

# %%
# TODO: set control/treatment visitors & conversions
# TODO: choose a prior (start with Beta(1,1))
# TODO: compute posterior parameters
# TODO: draw Monte-Carlo samples and compute
#       P(treatment > control), expected lift, P(lift > 0.01)

# %% [markdown]
# ## 3. Bayesian means for Familiar

# %%
# TODO: write posterior_mean_samples(x, ...) using the t-distribution construction
# TODO: draw post_vein and post_artery
# TODO: compute P(mu_Vein > 71) and P(mu_Vein > mu_Artery)
# TODO: compute 95% HDIs for the Vein mean and for the difference

# %% [markdown]
# ## 4. ROPE analysis

# %%
# TODO: choose a ROPE (e.g. ±0.5 years)
# TODO: report P(in ROPE), P(above), P(below)

# %% [markdown]
# ## 5. Alternate implementations
# - Analytic Beta quantiles / CDF
# - Sensitivity to stronger priors
# - Bootstrap resampling of the mean

# %%
# TODO: implement at least two of the three alternates

# %% [markdown]
# ## 6. More practice
# Answer the four practice questions listed in the Solution notebook (smaller experiment, P(>75), P(>78), new ROPE, threshold τ).

# %% [markdown]
# ## 7. Simulation section

# %%
# TODO: implement a function that estimates how often P(T>C) exceeds 0.95
#       under different sample sizes (and optionally different prior strengths)
# TODO: explore the effect of a Normal prior centred at 0 with varying strength
#       on P(diff > 0) for the Familiar packs

# %% [markdown]
# ## 8. Write three audience-specific conclusions
# 1. Executive (≤ 25 words)
# 2. Product / marketing (action + uncertainty)
# 3. Technical (probabilities, HDI, prior sensitivity)
