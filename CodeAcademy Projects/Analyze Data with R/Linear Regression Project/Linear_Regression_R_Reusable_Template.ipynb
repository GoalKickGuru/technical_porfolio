# %% [markdown]
# # Linear Regression Reusable Template (R)
#
# Copy this notebook for any new continuous-response problem. Replace the placeholder dataset and variable names, then follow the section order.
#
# **Audience note:** After the analysis, write a 4–6 sentence narrative tailored to one of: analyst / executive / non-specialist learner.

# %% [markdown]
# ## 1. Setup

# %%
library(ggplot2)
# library(broom)   # optional
set.seed(123)
theme_set(theme_minimal())

# %% [markdown]
# ## 2. Load & inspect data
# Replace `mydata` with your data.frame.

# %%
# mydata <- ...
# head(mydata); str(mydata); summary(mydata)

# %% [markdown]
# ## 3. Assumption checks

# %%
# ggplot(mydata, aes(x_var, y_var)) + geom_point()
# cor.test(mydata$x_var, mydata$y_var)
# ggplot(mydata, aes(y = x_var)) + geom_boxplot()

# %% [markdown]
# ## 4. Train / test split

# %%
# idx <- sample(c(TRUE, FALSE), nrow(mydata), replace = TRUE, prob = c(0.6, 0.4))
# train <- mydata[idx, ]; test <- mydata[!idx, ]

# %% [markdown]
# ## 5. Simple model + assessment

# %%
# mod <- lm(y_var ~ x_var, data = train)
# sigma(mod); summary(mod)$r.squared; summary(mod)

# %% [markdown]
# ## 6. Residual diagnostics + LOESS

# %%
# train$estimate <- predict(mod); train$resid <- residuals(mod)
# ggplot(train, aes(x_var, y_var)) + geom_point() +
#   geom_point(aes(y = estimate), color = "blue") +
#   geom_segment(aes(xend = x_var, yend = estimate), color = "gray")
# ggplot(train, aes(x_var, y_var)) + geom_point() +
#   geom_smooth(method = "lm") + geom_smooth(se = FALSE, color = "red")

# %% [markdown]
# ## 7. Multiple model (optional)

# %%
# mod_m <- lm(y_var ~ x_var + z_var, data = train)
# summary(mod_m)

# %% [markdown]
# ## 8. Quick Monte-Carlo (optional knobs)

# %%
# n_obs <- 50; noise_sd <- 15; n_sims <- 200; true_b1 <- 3.9
# ... (copy engine from Solution notebook and adapt)

# %% [markdown]
# ## 9. Audience narrative
# Write 4–6 sentences for your chosen audience here.

# %%
# cat("Your narrative...")
