# %% [markdown]
# # What Drives Your Loan's Interest Rate? A Linear Regression Analysis of Simulated Bank Loan Data
# ### 📝 SKELETON NOTEBOOK — fill in the `# TODO` sections
#
# **Business question:** For personal loans originated by a bank, how do a borrower's
# credit score, debt-to-income ratio, income, loan amount/term, employment history, and
# loan purpose relate to the **interest rate** they are charged? Can you build a linear
# regression model that explains and predicts pricing from these characteristics?
#
# **Dataset:** `bank_loans_sim.csv` — a simulated consumer-lending dataset (5,214 loan
# applications).
#
# | Column | Description |
# |---|---|
# | `row_id` / `loan_id` | Row / loan identifiers |
# | `credit_score` | FICO-style score 300-850 (`0` = "thin file" / no score on record) |
# | `annual_income` | Self-reported annual income in USD (`-1` = applicant declined to disclose) |
# | `employment_years` | Years at current employer (`99` = not applicable / not collected) |
# | `home_ownership` | `MORTGAGE`, `RENT`, `OWN`, `OTHER` |
# | `loan_purpose` | Stated reason for the loan |
# | `loan_amount` | Amount requested/originated, in USD |
# | `term_months` | Loan term, 36 or 60 months |
# | `verified_income` | `Verified`, `Source Verified`, or `Not Verified` |
# | `delinq_2yr` | Number of delinquencies in the past 2 years |
# | `dti` | Debt-to-income ratio (%) — investigate this one carefully in Step 2 |
# | `interest_rate` | Annual interest rate assigned to the loan (%) — **our outcome** |
# | `loan_status` | `Fully Paid`, `Current`, or `Charged Off` — not a predictor here; save it for a follow-up project |
#
# This project follows the four-stage workflow: **(1) confirm data assumptions, (2) build
# a model on training data, (3) assess model fit, (4) analyze model results**.
#
# > 💡 A completed reference solution is in `02_project_solution.ipynb` if you get stuck —
# > try each step yourself first! `03_project_cheatsheet.ipynb` has quick syntax lookups.

# %% [markdown]
# ## Step 0 — Setup
# Import the libraries you'll need: `pandas`, `numpy`, `matplotlib.pyplot`, `seaborn`, `statsmodels`, `scipy.stats`, and the relevant pieces of `sklearn`.

# %%
# TODO: import pandas, numpy, matplotlib.pyplot, seaborn, statsmodels.api,
# statsmodels.formula.api, scipy.stats, and train_test_split / metrics from sklearn.
# Also set a random seed for reproducibility.

# %% [markdown]
# ## Step 1 — Load and Inspect the Data
#
# **Instructions:**
# 1. Load `bank_loans_sim.csv` into a DataFrame called `raw`.
# 2. Use `.shape`, `.info()`, `.head()`, and `.describe(include="all")` to get a full
#    picture: how many rows/columns, what types, what ranges.
# 3. Write down (in a markdown cell) at least three things that look suspicious or need
#    further investigation before modeling — check the min/max of every numeric column
#    carefully.

# %%
# TODO: load the CSV into `raw`

# %%
# TODO: inspect shape / info

# %%
# TODO: inspect head() and describe(include='all')

# %% [markdown]
# **Your observations:** *(replace this text)*
# - ...
# - ...
# - ...

# %% [markdown]
# ## Step 2 — Data Cleaning

# %% [markdown]
# ### 2.1 Remove exact duplicate loan records
#
# **Instructions:**
# 1. Count how many rows are exact duplicates of another row, **ignoring** the `row_id`
#    column (hint: `.duplicated(subset=...)`).
# 2. Drop them, keeping one copy of each, and save the result as `df`. Print the row count
#    before and after.

# %%
# TODO: find and drop exact duplicate rows (ignoring row_id) -> df

# %% [markdown]
# ### 2.2 Replace sentinel/missing codes with `NaN`
#
# **Instructions:**
# Based on your Step 1 observations, identify the sentinel codes used for missing data in
# `credit_score`, `annual_income`, `employment_years`, and `interest_rate`. Count how many
# rows use each sentinel, then replace them all with `np.nan`.

# %%
# TODO: count and replace sentinel codes in credit_score, annual_income,
# employment_years, and interest_rate with NaN

# %% [markdown]
# ### 2.3 Investigate `dti` — is the zero real?
#
# `dti` (debt-to-income) is a *ratio* — it requires a known income to compute.
#
# **Instructions:**
# 1. Build a cross-tab of `annual_income.isna()` against `dti == 0`. What do you notice?
# 2. **Think about it:** could a `dti` of exactly 0 be a genuine "this borrower has no
#    debt" signal, or could it be something the loan system defaults to when it can't
#    actually compute a ratio? Which explanation fits the cross-tab better?
# 3. Based on your answer, set the appropriate `dti` values to `NaN` rather than treating
#    them as real zeros.

# %%
# TODO: cross-tab annual_income missingness against dti == 0

# %% [markdown]
# **Your reasoning and decision:** *(replace this text)*

# %%
# TODO: null out the structural-zero dti values

# %% [markdown]
# ### 2.4 Drop rows with missing values in required fields
#
# **Instructions:**
# Decide which columns are *required* for this analysis (you need a valid value in each
# to model interest-rate pricing meaningfully). Drop rows missing any required field and
# save the result as `analysis_df`. Print the final sample size.

# %%
# TODO: build `analysis_df` by dropping rows missing required fields

# %% [markdown]
# ## Step 3 — Checking the Linearity Assumption
#
# **Instructions:**
# 1. Make a scatterplot of `credit_score` (x) vs `interest_rate` (y). Describe the shape
#    and compute the Pearson correlation.
# 2. Check the skew of `loan_amount` and `annual_income` (hist + `.skew()`). If either is
#    strongly skewed, create log-transformed versions (`log_loan_amount`,
#    `log_annual_income`) to use as predictors instead of the raw values.
# 3. Note: should you log-transform the **outcome** (`interest_rate`) here too? Why or why
#    not? (Hint: think about what kind of variable it is and what range it takes.)

# %%
# TODO: scatterplot + correlation of credit_score vs interest_rate

# %%
# TODO: check skew of loan_amount and annual_income; create log-transformed versions

# %% [markdown]
# **Your decision about transforming the outcome:** *(replace this text)*

# %% [markdown]
# ## Step 4 — Outlier Treatment
#
# **Instructions:**
# 1. Make box plots of `interest_rate`, `dti`, `credit_score`, and `log_loan_amount`.
# 2. Write (or reuse) an `iqr_bounds()` helper function and use it to find and remove
#    outlier rows in `dti`. Save the result as `clean_df`. Print sample sizes before and
#    after.

# %%
# TODO: box plots for interest_rate, dti, credit_score, log_loan_amount

# %%
# TODO: define iqr_bounds() and use it to find/remove dti outliers -> clean_df

# %% [markdown]
# ## Step 5 — Train/Test Split
#
# **Instructions:**
# Split `clean_df` into `train` (80%) and `test` (20%) with a fixed `random_state`. Print
# the size of each set.

# %%
# TODO: train, test = train_test_split(...)

# %% [markdown]
# ## Step 6 — Building a Simple Linear Regression Model
#
# **Instructions:**
# Fit a simple linear regression of `interest_rate` on `credit_score` alone, using
# `statsmodels.formula.api.ols`. Save the fitted model as `model_simple` and print its
# `.summary()`.

# %%
# TODO: model_simple = smf.ols(...).fit()
# TODO: print(model_simple.summary())

# %% [markdown]
# ## Step 7 — Quantifying Model Fit
#
# **Instructions:**
# Extract and print the R-squared and Residual Standard Error (RSE) of `model_simple`. In
# a sentence, explain what each number tells a non-technical stakeholder about how good
# the pricing model is so far.

# %%
# TODO: compute and print R-squared and RSE

# %% [markdown]
# ## Step 8 — Checking Model Residuals
#
# **Instructions:**
# 1. Plot residuals vs. fitted values with a reference line at 0.
# 2. Make a Normal Q-Q plot of the residuals.
# 3. Do the residuals look reasonably well-behaved? Explain.

# %%
# TODO: residuals vs fitted plot

# %%
# TODO: Q-Q plot

# %% [markdown]
# **Your interpretation:** *(replace this text)*

# %% [markdown]
# ## Step 9 — Visualizing Model Fit
#
# **Instructions:**
# Plot the scatter of `credit_score` vs `interest_rate` in the training data along with
# both the fitted linear regression line and a LOWESS smoother. Do they agree?

# %%
# TODO: combined scatter + linear fit + LOWESS plot

# %% [markdown]
# ## Step 10 — Reading and Interpreting the Model Results
#
# **Instructions:**
# 1. Extract $\beta_0$, $\beta_1$, the p-value, and the 95% CI for `credit_score` from
#    `model_simple`.
# 2. Write one sentence interpreting $\beta_1$ in plain English for a loan officer who has
#    never seen a regression output before.

# %%
# TODO: extract beta0, beta1, p-value, confidence interval; write your interpretation

# %% [markdown]
# ## Step 11 — Making Predictions and Evaluating on the Test Set
#
# **Instructions:**
# 1. Generate predictions on the `test` set.
# 2. Compute the test-set R-squared and RMSE.
# 3. Compute the RMSE of a naive baseline that always predicts the training mean of
#    `interest_rate`. Does your model beat it? By how much?

# %%
# TODO: generate predictions on the test set

# %%
# TODO: compute test R-squared, RMSE, and compare to a naive baseline

# %% [markdown]
# ## Step 12 — Multiple Linear Regression
#
# **Instructions:**
# Extend the model to include `dti`, `log_loan_amount`, `log_annual_income`,
# `employment_years`, `delinq_2yr`, `term_months`, `loan_purpose`, `verified_income`, and
# `home_ownership`. Wrap categorical columns in `C(...)` inside the formula string. Save
# the model as `model_multi` and print its summary.

# %%
# TODO: fit model_multi with the extended formula, print summary

# %% [markdown]
# ## Step 13 — Assessing the Multiple Regression Model
#
# **Instructions:**
# 1. Compare R-squared **and adjusted R-squared** of `model_simple` vs `model_multi`.
# 2. Run a nested-model F-test (`anova_lm`) comparing the two models.
# 3. Compute VIFs for the multiple model's numeric/dummy-encoded predictors. Are any
#    concerningly high (rule of thumb: > 5-10)?

# %%
# TODO: compare R-squared / adjusted R-squared for both models

# %%
# TODO: nested F-test with anova_lm

# %%
# TODO: compute VIFs for the multiple model's predictors

# %% [markdown]
# ## Step 14 — Interpreting the Multiple Regression Coefficients
#
# **Instructions:**
# 1. Build a coefficient table with p-values for `model_multi`.
# 2. Evaluate `model_multi` on the test set (R-squared and RMSE) and compare to
#    `model_simple`.
# 3. Write 3-4 sentences interpreting the practical meaning of the key coefficients
#    (credit score, DTI, loan amount, income, delinquencies). Remember categorical
#    coefficients are relative to a left-out reference category.

# %%
# TODO: coefficient table with p-values

# %%
# TODO: evaluate model_multi on the test set

# %% [markdown]
# **Your interpretation:** *(replace this text)*

# %% [markdown]
# ## Step 15 — Limitations and Next Steps
#
# **Instructions:** Write a short "limitations" section addressing at least:
# 1. This is simulated data — what does that mean for how you should talk about the
#    specific coefficient values?
# 2. Who got excluded from `analysis_df`, and how might they differ from who's left?
# 3. Why can't you use `loan_status` as a predictor in this particular model?
# 4. Suggest one concrete next step (a new variable, a different model type, more data).

# %% [markdown]
# *(write your limitations discussion here)*

# %% [markdown]
# ## Step 16 — Executive Summary
#
# **Instructions:** Write a 4-6 bullet executive summary for a non-technical audience:
# what question you asked, what you found, how confident you are, and what you'd want to
# do next.

# %% [markdown]
# *(write your executive summary here)*
