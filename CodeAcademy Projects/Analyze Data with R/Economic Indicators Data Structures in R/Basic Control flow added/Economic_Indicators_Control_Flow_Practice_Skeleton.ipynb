# %% [markdown]
# # Economic Indicators + Control Flow in R
# ## Practice Skeleton — Adding Decision-Making to Macroeconomic Analysis
#
# **Goal:** Extend the Economic Indicators data-structures project with R control flow (`if`, `else`, `else if`, nested conditionals). You will turn raw indicator vectors and a data frame into policy signals, regime labels and scenario recommendations.
#
# **Prerequisites:** Basic familiarity with vectors and data frames (see the companion Economic Indicators Data Structures project).
#
# **How to use this notebook**
# 1. Read each markdown section carefully.
# 2. Write code in the cells marked `# YOUR CODE HERE`.
# 3. Run the cell and check the printed output.
# 4. Use the Solution notebook when stuck or to study alternate patterns.
# 5. Complete the More Practice and Simulation sections.
#
# **Flowchart**
#
# ![Economic Indicators + Control Flow](economic_indicators_control_flow_flowchart.png)

# %% [markdown]
# ## 0. Shared Economic Data (already provided)
#
# We re-create the core objects from the previous project so this notebook is self-contained.

# %%
# Years and indicators (2017-2026)
years <- 2017:2026
inflation <- c(2.1, 2.4, 1.8, 1.2, 4.7, 8.0, 4.1, 3.4, 2.9, 2.5)
gdp_growth <- c(2.3, 2.9, 2.3, -2.8, 5.9, 2.1, 2.5, 2.0, 1.8, 2.2)
unemployment <- c(4.4, 3.9, 3.7, 8.1, 5.4, 3.6, 3.7, 4.0, 4.2, 4.1)

# Mini dashboard for recent years
macro_df <- data.frame(
  year         = 2022:2026,
  inflation    = c(8.0, 4.1, 3.4, 2.9, 2.5),
  gdp_growth   = c(1.9, 2.5, 2.1, 1.8, 2.0),
  unemployment = c(3.6, 3.7, 4.0, 4.2, 4.1),
  stringsAsFactors = FALSE
)

print(macro_df)

# %% [markdown]
# ## 1. Simple `if` — Single Threshold Check
#
# ### Theory
# ```r
# if (condition) {
#   # code that runs only when condition is TRUE
# }
# ```
# Condition must evaluate to a single `TRUE` or `FALSE`. Use comparison operators (`>`, `<`, `>=`, `<=`, `==`, `!=`) and logical operators (`&`, `|`, `!`).
#
# ### Task 1.1
# Look at the most recent inflation value (`inflation[length(inflation)]` or `tail(inflation, 1)`).
#
# If it is **greater than 3.0**, print the message `"Inflation still above comfort zone — monitor closely."`
#
# (If the condition is false, nothing should be printed.)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 1.2
# Using the `macro_df` data frame, check whether the **first row’s** unemployment is below 4.0.
#
# If yes, print `"Labour market remains tight."`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 2. `if` / `else` — Binary Policy Choice
#
# ### Theory
# ```r
# if (condition) {
#   # path A
# } else {
#   # path B  (runs when condition is FALSE)
# }
# ```
# Exactly one of the two blocks executes.
#
# ### Task 2.1
# Compute the average of the entire `gdp_growth` vector.
#
# - If the average is **positive**, print `"Economy expanded on average over the decade."`
# - Otherwise print `"Economy contracted on average over the decade."`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task 2.2 — Funding-style decision (adapted to economics)
# Imagine a central-bank “policy budget” of 100 units that must be split across 4 priority areas.
#
# ```r
# policy_budget <- 100
# n_priorities  <- 4
# units_per_priority <- policy_budget / n_priorities
# ```
#
# If `units_per_priority >= 25`, print `"Adequate resources for each priority."`
# Else print `"Resources stretched — prioritisation required."`

# %%
# YOUR CODE HERE
policy_budget <- 100
n_priorities  <- 4
units_per_priority <- policy_budget / n_priorities

# complete the if / else

# %% [markdown]
# ## 3. `else if` — Multi-Tier Inflation Regimes
#
# ### Theory
# ```r
# if (cond1) {
#   # ...
# } else if (cond2) {
#   # ...
# } else if (cond3) {
#   # ...
# } else {
#   # default
# }
# ```
# Conditions are checked **in order**. The first true condition wins; the rest are skipped.
#
# ### Task 3.1
# Using the **latest** inflation value, assign a regime label:
#
# - `>= 5` → `"High inflation regime"`
# - `>= 3` and `< 5` → `"Elevated inflation"`
# - `>= 2` and `< 3` → `"Target-consistent"`
# - otherwise → `"Low inflation / risk of undershoot"`
#
# Print the label.

# %%
# YOUR CODE HERE
latest_inf <- tail(inflation, 1)

# write the if / else if / else chain

# %% [markdown]
# ### Task 3.2
# Do the same classification for **every** year in the `inflation` vector and store the results in a character vector called `regime`.
#
# Hint: you can use a `for` loop over the indices, or think about `ifelse` (shown in the Solution as an alternate).
# For now, a simple loop is fine.

# %%
# YOUR CODE HERE
regime <- character(length(inflation))

# fill regime[i] for each i
print(data.frame(year = years, inflation = inflation, regime = regime))

# %% [markdown]
# ## 4. Nested Conditionals — Multi-Criteria Policy
#
# ### Theory
# You can place an entire `if/else` block **inside** another. This is useful when a second decision only makes sense after a first condition is true.
#
# ### Task 4.1 — Growth + Unemployment joint check
# Using the **most recent** values of GDP growth and unemployment:
#
# ```r
# g <- tail(gdp_growth, 1)
# u <- tail(unemployment, 1)
# ```
#
# - If growth is **positive**:
#   - If unemployment is **below 4.0**, print `"Goldilocks: positive growth + tight labour market."`
#   - Else print `"Growth positive but labour market softening."`
# - Else (growth ≤ 0):
#   - print `"Negative or zero growth — prioritise stabilisation."`

# %%
# YOUR CODE HERE
g <- tail(gdp_growth, 1)
u <- tail(unemployment, 1)

# nested if / else

# %% [markdown]
# ### Task 4.2 — Nested “access” style decision (policy committee)
# A fictional policy committee has two access levels:
#
# - `access_briefing` (starts FALSE)
# - `access_detailed_model` (starts FALSE)
#
# Rules (mirroring the secret-event example in the lesson):
#
# 1. If the analyst’s `experience_years >= 5`:
#    - set `access_briefing <- TRUE` and print `"Briefing access granted."`
#    - Nested: if they also know the correct `model_codeword`, set `access_detailed_model <- TRUE` and print `"Detailed model access granted."`
# 2. Else if `experience_years >= 2` **and** `current_hour < 17` (still in office hours):
#    - set `access_briefing <- TRUE` and print `"Limited briefing access until 17:00."`
# 3. Else:
#    - print `"Access denied — gain more experience or wait for office hours."`
#
# Use the starter variables below.

# %%
access_briefing      <- FALSE
access_detailed_model <- FALSE
experience_years     <- 6
current_hour         <- 14
possible_codeword    <- "phillips"
real_codeword        <- "phillips"

# YOUR CODE HERE — implement the nested decision tree
print(paste("access_briefing:", access_briefing))
print(paste("access_detailed_model:", access_detailed_model))

# %% [markdown]
# ## 5. More Practice
#
# ### Practice A — Vectorised regime with `ifelse` (preview)
# Although loops work, R prefers vectorised tools.
# Use nested `ifelse()` to create the same `regime` vector **without** an explicit loop.
# Print the result next to the years.

# %%
# YOUR CODE HERE
# regime_vec <- ifelse( ... , ifelse( ... , ...))

# %% [markdown]
# ### Practice B — Filter the data frame
# Create a new data frame `high_inf_years` that contains only the rows of `macro_df` where inflation is **greater than or equal to 3.0**.
#
# Hint: you can use a logical vector inside `[ , ]` or an `if` inside a loop that builds the result. The logical-index way is preferred.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 6. Simulation — Parameterised Policy Branching
#
# Change the parameters below and re-run the cell to see how the recommended policy stance changes.
#
# ```r
# current_inflation   <- 3.8
# current_growth      <- 1.2
# current_unemp       <- 4.5
# inflation_target    <- 2.0
# growth_floor        <- 1.0
# ```
#
# ### Required logic
# Write a single nested / else-if structure that prints **one** of the following stances:
#
# - `"Aggressive tightening"` — inflation more than 2 pp above target **and** growth above the floor
# - `"Moderate tightening"` — inflation above target but growth is weak
# - `"Patient / data-dependent"` — inflation close to target
# - `"Easing bias"` — inflation below target
#
# Also print a short justification that mentions the actual numbers.

# %%
# Editable simulation parameters
current_inflation <- 3.8
current_growth    <- 1.2
current_unemp     <- 4.5
inflation_target  <- 2.0
growth_floor      <- 1.0

# YOUR CODE HERE — decision tree that prints stance + justification

# %% [markdown]
# ## End of Practice Skeleton
#
# You have now added full control-flow capability on top of the economic data structures:
#
# | Control-flow tool | Economic use |
# |-------------------|--------------|
# | simple `if`       | single threshold alerts |
# | `if / else`       | binary policy choices |
# | `else if` chain   | multi-tier regimes |
# | nested conditionals | joint growth + unemployment decisions |
# | simulation        | scenario analysis for policy committees |
#
# Proceed to the **Solution** notebook for complete code, vectorised alternates (`ifelse`, `case_when` style), and a richer simulation function.
