# %% [markdown]
# # Explore R Data Structures
# ## Practice Skeleton — Deep Dive into Vectors, Matrices, Lists & Data Frames
#
# **Goal:** Move beyond basic creation and indexing. Explore coercion rules, structure properties, nested objects, performance implications, and decision criteria for choosing the right structure — using macroeconomic examples throughout.
#
# **How to use**
# 1. Read the exploration questions in each section.
# 2. Write code that answers them (replace `# YOUR CODE HERE`).
# 3. Run cells and observe printed output / structure.
# 4. Compare with the Solution notebook when ready.
# 5. Complete the Simulation & Decision section at the end.
#
# **Flowchart of Exploration Path**
#
# ![R Data Structures Exploration Flowchart](r_data_structures_exploration_flowchart.png)

# %% [markdown]
# ## 1. Exploring Vectors — Atomic Nature & Coercion
#
# Vectors are the foundation. Everything in R is built on them.
#
# ### Exploration 1.1 — Type coercion
# What happens when you mix types inside `c()`?
#
# Create three vectors:
# - `v_num_char` that mixes a number and a string
# - `v_num_logical` that mixes a number and `TRUE`
# - `v_char_logical` that mixes a string and `FALSE`
#
# For each, print the vector **and** its `typeof()`.
# Write a one-line comment explaining the coercion rule you observe.

# %%
# YOUR CODE HERE
v_num_char <- 
v_num_logical <- 
v_char_logical <- 

print(v_num_char); print(typeof(v_num_char))
print(v_num_logical); print(typeof(v_num_logical))
print(v_char_logical); print(typeof(v_char_logical))
# Comment:

# %% [markdown]
# ### Exploration 1.2 — Attributes & names
# Vectors can carry names (an attribute).
#
# 1. Create `inflation` = `c(2.1, 2.4, 1.8, 1.2, 4.7)` for years 2020–2024.
# 2. Attach year names with `names(inflation) <- 2020:2024`.
# 3. Extract the 2022 value **by name**.
# 4. Print `attributes(inflation)` and `str(inflation)`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Exploration 1.3 — Recycling rules
# What does R do when you add two vectors of different lengths?
#
# Try:
# ```r
# c(1,2,3,4) + c(10,20)
# c(1,2,3) + c(10,20)
# ```
# Print the results and note any warning.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 2. Exploring Matrices — Dimensions & Filling Order
#
# ### Exploration 2.1 — byrow vs default
# Create the same 3×4 matrix of numbers 1–12 **twice**:
# - once with default (column-major) filling
# - once with `byrow = TRUE`
#
# Print both and visually confirm the difference.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Exploration 2.2 — Dimension attributes
# 1. Create a matrix `m` of 2 rows × 5 columns filled with `0`.
# 2. Change its dimensions **in place** to 5 × 2 using `dim(m) <- c(5,2)`.
# 3. Print the matrix before and after. What happened to the data layout?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 3. Exploring Lists — Heterogeneity & Nesting
#
# ### Exploration 3.1 — Nested list for a country dossier
# Build a nested list `country_dossier` that contains:
# - `$meta` = list of region name and currency
# - `$series` = list of two numeric vectors (inflation and gdp_growth)
# - `$flags` = logical vector of length 2 (has_forecast, rate_decision_pending)
#
# Print the whole object with `str(country_dossier)`.
# Extract the inflation series with double-bracket and `$` notation.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Exploration 3.2 — List vs vector of lists
# Create:
# - a plain vector of three country names
# - a list of three country names
#
# Print `typeof()` and `class()` of both. Why does the second stay a list?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 4. Exploring Data Frames — Columns, Types & Structure
#
# ### Exploration 4.1 — Column types stay independent
# Create a data frame with:
# - a character column `country`
# - a numeric column `inflation`
# - a logical column `is_advanced`
#
# Print `str(df)` and `sapply(df, typeof)`. Confirm that each column keeps its own type.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Exploration 4.2 — data.frame vs matrix coercion
# 1. Create a pure numeric matrix 3×3.
# 2. Convert it to a data frame with `as.data.frame()`.
# 3. Convert the data frame back to a matrix with `as.matrix()`.
# 4. Observe what happens to column names and types.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 5. Structure Decision Simulation
#
# You receive new data every quarter. Decide which structure to use.
#
# **Scenario parameters** (edit freely):
# ```r
# n_countries   <- 4
# n_years       <- 6
# mixed_info    <- TRUE   # do we also need text notes and flags?
# need_math     <- TRUE   # will we run matrix algebra later?
# ```
#
# ### Task
# Write code that prints a recommendation:
# - If pure numeric + need_math → prefer **matrix**
# - If mixed types or notes → prefer **list** or **data.frame**
# - If single series → **vector**
# - Always show a small example object of the recommended type.

# %%
# Editable parameters
n_countries <- 4
n_years     <- 6
mixed_info  <- TRUE
need_math   <- FALSE

# YOUR CODE HERE — decision logic + example object

# %% [markdown]
# ## End of Exploration Skeleton
#
# You have now probed coercion, attributes, nesting, dimension changes and decision criteria.
# Proceed to the **Solution** notebook for complete answers, alternate patterns, and a richer simulation.
