# %% [markdown]
# # Bank NPL Rates by Asset Size — Practice Skeleton
#
# **Goal:** Investigate how a bank’s size (total assets) relates to its non-performing loan (NPL) rate across 158 banks. Practice extracting vectors with `dplyr::pull()`, computing quantiles, splitting data by a threshold (median assets), and comparing distributions with histograms.
#
# **Data:** `data/bank_data.csv` — columns: `bank`, `npl_rate` (percent), `total_assets` (USD millions).
#
# **Banking context:** NPL rate is a key credit-risk and asset-quality indicator. Regulators, credit-risk teams, and ALCO committees watch it closely. Larger banks often have more diversified portfolios and stronger risk management, which can be associated with lower NPL rates (though causation is not claimed from a cross-section).
#
# **Audience notes (from the attached PDFs):**
# - **Data-literate / Credit Risk analysts:** comfortable with quartiles, histograms, Spearman correlation, and precise numeric summaries.
# - **Subject experts (Credit Risk / ALM / Supervisors):** skip basic definitions of NPL and assets; highlight regulatory and capital implications.
# - **Executives / Board / nonspecialists:** short attention span — lead with the headline (“Larger banks show materially lower NPL rates”) and one clear visual; avoid jargon.
# - Always match chart complexity and explanation depth to the audience.
#
# **How to use this notebook:**
# 1. Read each markdown step.
# 2. Fill in the code cells marked `# YOUR CODE HERE`.
# 3. Run the cell and compare with the expected behaviour described.
# 4. When stuck, open the companion **Solution** notebook.
# 5. After finishing the core tasks, complete **Alternate Code**, **More Practice**, and **Simulation**.
#
# ---
#
# ## Flowchart of the Desired Outcome
#
# ![Bank NPL Analysis Flowchart](bank_npl_flowchart.png)
#
# The flowchart shows the end-to-end pipeline: load → extract NPL rate → quartiles & histogram → extract assets & median → split into small/large banks → group-wise quartiles & histograms → interpret impact → optional simulation.

# %% [markdown]
# ## Step 0 — Setup & Load Packages
#
# Load the packages we need.

# %%
# load packages
library(ggplot2)
library(readr)
library(dplyr)

# %% [markdown]
# ## Step 1 — Access the Data
#
# We have imported a dataset containing NPL rates and total assets for different banks. The data live in the variable named `data`.
#
# - Inspect the first 6 rows with `head()`.
# - Look at the column names. What other pieces of information does this dataset contain?
# - You may want to comment out the `head()` call after looking at the data.

# %%
# import and inspect data
data <- read_csv("data/bank_data.csv")

# YOUR CODE HERE: inspect the first rows
# head(data)

# %% [markdown]
# ## Step 2 — Isolate the NPL Rate Column as a Vector
#
# Many of R’s statistical functions require a **numeric vector**, not a data-frame column.
#
# - Use `dplyr::pull()` (instead of `select()`) to extract the `npl_rate` column into a vector named `npl_rate`.
# - Pay attention to capitalization of the column name!

# %%
# npl rate vector
# YOUR CODE HERE
# npl_rate <- data %>%
#   pull(npl_rate)

# %% [markdown]
# ## Step 3 — Find the Quartiles
#
# Use R’s `quantile()` function to find the quartiles of `npl_rate`.
# Store the result in `npl_quartiles` and view it.

# %%
# npl rate quartiles
# YOUR CODE HERE
# npl_quartiles <- quantile(npl_rate)
# npl_quartiles

# %% [markdown]
# ## Step 4 — Plot the Histogram of NPL Rates
#
# By looking at the three quartile values you get a sense of the spread.
# Plot the histogram with:
#
# ```r
# hist(npl_rate)
# ```
#
# Does the shape match what you expected from the quartiles?

# %%
# plot histogram of npl rates
# YOUR CODE HERE
# hist(npl_rate)

# %% [markdown]
# ## Step 5 — Interpret an NPL Rate of 9 %
#
# If a bank has an NPL rate of **9 %**, does that fall in the first, second, third, or final quarter of the data?
#
# (Write a short answer in a comment or a new markdown cell after you run the quantiles.)

# %% [markdown]
# ## Step 6 — Isolate the Total Assets Column
#
# Total assets is a common measure of bank size. We will split the data into “small banks” and “large banks” using the median assets as the threshold.
#
# Extract the `total_assets` column into a numeric vector named `assets` (again using `pull()`).

# %%
# assets vector
# YOUR CODE HERE
# assets <- data %>%
#   pull(total_assets)

# %% [markdown]
# ## Step 7 — Find the Median Assets
#
# You can use `median()` or `quantile(assets, 0.5)`.
# Store the value in `median_assets` and print it.

# %%
# median assets
# YOUR CODE HERE
# median_assets <- median(assets)
# median_assets

# %% [markdown]
# ## Step 8 — Split the Data into Small-Bank and Large-Bank Groups
#
# - Create `small_npl` containing the **npl_rate** values for banks whose total assets are ≤ the median.
# - Create `large_npl` containing the **npl_rate** values for banks whose total assets are > the median.
#
# Hint (you can adapt this pattern):
#
# ```r
# small_npl <- data %>%
#   filter(total_assets <= median_assets) %>%
#   pull(npl_rate)
# ```

# %%
# small bank npl rate vector
# YOUR CODE HERE

# large bank npl rate vector
# YOUR CODE HERE

# %% [markdown]
# ## Step 9 — Quartiles of the Small-Bank Group
#
# Compute the quartiles of `small_npl` and store them in `small_npl_quartiles`. View the result.

# %%
# small bank npl quartiles
# YOUR CODE HERE
# small_npl_quartiles <- quantile(small_npl)
# small_npl_quartiles

# %% [markdown]
# ## Step 10 — Quartiles of the Large-Bank Group
#
# Do the same for the large banks → `large_npl_quartiles`.

# %%
# large bank npl quartiles
# YOUR CODE HERE
# large_npl_quartiles <- quantile(large_npl)
# large_npl_quartiles

# %% [markdown]
# ## Step 11 — Histograms of the Two Groups
#
# Plot the two histograms side-by-side (or one after the other) using different colours so you can compare the distributions:
#
# ```r
# hist(small_npl, col = "red", main = "Small Banks")
# hist(large_npl, col = "blue", main = "Large Banks")
# ```

# %%
# plot small bank histogram
# YOUR CODE HERE

# plot large bank histogram
# YOUR CODE HERE

# %% [markdown]
# ## Step 12 — Interpret an NPL Rate of 9 % Again
#
# Consider a bank with an NPL rate of **9 %**:
#
# - If the bank is in the **top half of asset size** (large banks), is 9 % in the 1st, 2nd, 3rd or 4th quarter of that group’s NPL distribution?
# - If the bank is in the **bottom half of asset size** (small banks), where does 9 % fall?
#
# Write your conclusions in a markdown cell.

# %% [markdown]
# ## Alternate Code Paths
#
# Try at least two of the following alternative approaches that achieve the same results:
#
# 1. Base-R extraction: `data$npl_rate` or `data[["npl_rate"]]` instead of `pull()`.
# 2. `quantile(..., probs = c(0.25, 0.5, 0.75))` or `fivenum()` / `summary()`.
# 3. Use `ifelse` or a logical index instead of `filter()` to split the groups.
# 4. `tapply` / `split` / `by` to compute quantiles by an asset-size-group factor.
# 5. `ggplot2` histograms instead of base `hist()`.

# %%
# ALTERNATE 1 — base-R column extraction + fivenum
# YOUR CODE HERE

# ALTERNATE 2 — logical indexing split
# YOUR CODE HERE

# %% [markdown]
# ## More Practice
#
# 1. Compute the **IQR** of the overall NPL rate and of each size group. Which group is more spread out?
# 2. Calculate the **mean** and **median** for each group. Is the distribution skewed? (mean vs median)
# 3. Add a third group: “mid-sized banks” (between the 25th and 75th percentiles of assets) and compare its NPL quartiles.
# 4. (Optional) Compute Spearman correlation between `npl_rate` and `total_assets`. What does the sign tell you?

# %%
# MORE PRACTICE — IQR, mean/median, extra groups, correlation
# YOUR CODE HERE

# %% [markdown]
# ## Simulation Section
#
# Modify a few values and observe how the results change.
#
# **Ideas to try:**
#
# - Change the split threshold from the **median** to the **mean**, or to the 40th / 60th percentile of assets.
# - Add random noise to NPL rates (`npl_rate + rnorm(n, 0, sd)`) and re-compute the group quartiles.
# - Sub-sample 50 % of the banks and see how stable the quartile differences are.
# - Monte-Carlo: repeat the median-split many times after adding noise; collect the difference in group medians and plot a histogram of that difference.
#
# Write a small parameterised block so you can change `split_prob`, `noise_sd`, or `n_sim` and re-run.

# %%
# SIMULATION — parameterised experiment
# set.seed(123)
# split_prob <- 0.5          # change me (0.4, 0.5, 0.6 ...)
# noise_sd   <- 0            # change me (0, 0.5, 1 ...)
# n_sim      <- 200          # change me

# YOUR CODE HERE

# %% [markdown]
# ## Key Reflection (Audience Adaptation)
#
# After finishing the analysis, write two short paragraphs:
#
# 1. **For a Credit Risk analyst / technical colleague** — precise numbers, quartile values, possible next steps (correlation, regression, controls for business model or geography).
# 2. **For a busy executive or Board member** — one headline finding, one supporting visual description, and one concrete implication for capital or portfolio strategy.
#
# Keep the language appropriate to each audience’s data literacy and time span (see the attached audience PDFs).
