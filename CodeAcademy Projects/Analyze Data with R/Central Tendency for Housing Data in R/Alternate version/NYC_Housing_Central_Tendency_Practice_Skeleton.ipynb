# %% [markdown]
# # NYC One-Bedroom Rents — Central Tendency (Mean, Median, Mode) — Practice Skeleton
#
# **Goal:** Calculate and interpret the mean, median, and mode of one-bedroom apartment rents in three New York City boroughs (Brooklyn, Manhattan, Queens). Use the results to compare cost of living and practice audience-aware messaging.
#
# **Data:** `data/brooklyn-one-bed.csv`, `data/manhattan-one-bed.csv`, `data/queens-one-bed.csv` (synthetic but realistic right-skewed rent distributions).
#
# **Flowchart of desired outcome:**
#
# ![Flowchart](nyc_housing_central_tendency_flowchart.png)
#
# ---
# ## Learning Objectives
# 1. Load multiple CSVs and extract numeric rent vectors.
# 2. Compute mean (manual + `mean()`).
# 3. Compute median (sort + `median()`).
# 4. Compute mode (frequency table / `DescTools::Mode`).
# 5. Compare the three boroughs and diagnose skew.
# 6. Overlay statistics on histograms.
# 7. Write short interpretations for different audiences (analyst / executive / nonspecialist).
# 8. Explore alternate implementations, extra practice questions, and a Monte-Carlo simulation.

# %% [markdown]
# ## Step 0 — Setup & Load Data
#
# Load the three CSV files. Each has a column named `rent`. Inspect structure and a quick summary for one borough.

# %%
# TODO: load the three data frames (use read.csv or readr::read_csv)
brooklyn_one_bed <- NULL
manhattan_one_bed <- NULL
queens_one_bed <- NULL

# TODO: extract the rent vectors
brooklyn_price <- NULL
manhattan_price <- NULL
queens_price <- NULL

# TODO: print head / summary of at least one vector

# %% [markdown]
# ## Step 1 — Mean (Average Rent)
#
# Calculate the arithmetic mean for each borough.
#
# - Manual: `sum(x) / length(x)`
# - Built-in: `mean(x)`
#
# Save results to `brooklyn_mean`, `manhattan_mean`, `queens_mean` and print them (rounded to 2 decimals is nice).

# %%
# TODO: Brooklyn mean
brooklyn_mean <- NULL

# TODO: Manhattan mean
manhattan_mean <- NULL

# TODO: Queens mean
queens_mean <- NULL

# print the three means

# %% [markdown]
# ## Step 2 — Median (Typical Rent)
#
# The median is the middle value after sorting. It is robust to high-end luxury outliers common in housing data.
#
# Save to `brooklyn_median`, `manhattan_median`, `queens_median`.

# %%
# TODO: compute the three medians
brooklyn_median <- NULL
manhattan_median <- NULL
queens_median <- NULL

# print them

# %% [markdown]
# ## Step 3 — Mode (Most Common Listing Price)
#
# The mode is the value that appears most frequently. Housing data often has a clear “popular” price point (e.g. $2,500 listings).
#
# Options:
# - `table()` + find the name with maximum count
# - `DescTools::Mode()` (already a common package for this)
#
# Save to `brooklyn_mode`, `manhattan_mode`, `queens_mode`.

# %%
# TODO: compute modes (you may load DescTools if desired)
# library(DescTools)
brooklyn_mode <- NULL
manhattan_mode <- NULL
queens_mode <- NULL

# print them

# %% [markdown]
# ## Step 4 — Quick Comparison Table
#
# Build a small data frame or just print a tidy summary that shows mean / median / mode side-by-side for the three boroughs. Notice the ordering Mode ≤ Median ≤ Mean in each borough (classic right skew).

# %%
# TODO: create a comparison summary (data.frame or printed matrix)

# %% [markdown]
# ## Step 5 — Histograms with Central-Tendency Lines
#
# Create a histogram for at least one borough (or all three). Overlay vertical lines for mean (solid), median (dashed), and mode (dotted). Use different colors.
#
# Base R: `hist()` + `abline()`.

# %%
# TODO: hist + abline for Brooklyn (or a 1x3 layout)

# %% [markdown]
# ## Step 6 — What Does the Data Tell Us?
#
# Write 3–5 sentences answering:
#
# 1. Which borough is most expensive on average? On a typical (median) listing?
# 2. Why is the mean higher than the median in every borough?
# 3. What does the mode represent for a renter searching listings?
#
# (You will later adapt the same facts for different audiences.)

# %%
# Write your interpretation as comments or cat() statements

# %% [markdown]
# ## Step 7 — Assumptions
#
# List at least two assumptions you are making when you claim “Manhattan is more expensive than Queens.”
#
# Examples to consider: representativeness of the sample, time period, apartment quality / amenities held constant, selection bias from the data source, etc.

# %%
# Your assumptions here

# %% [markdown]
# ## Alternate Code Paths (Practice)
#
# Try at least one alternate way to obtain each statistic:
#
# - Mean without `mean()` (sum / length)
# - Median by explicit sorting and indexing
# - Mode with `table()` only (no DescTools)

# %%
# Alternate mean, median, mode implementations

# %% [markdown]
# ## More Practice
#
# 1. Compute the interquartile range (IQR) for each borough. Which has the widest spread?
# 2. What percentage of Brooklyn listings are above the Brooklyn mean?
# 3. Create a single data frame that stacks all three boroughs with a `borough` factor and compute group-wise mean/median with `tapply` or `aggregate`.

# %%
# More practice solutions space

# %% [markdown]
# ## Simulation Section
#
# Monte-Carlo sensitivity: take the Brooklyn rents, add Gaussian noise of different standard deviations (e.g. $50, $150, $300), re-compute mean / median / mode many times, and examine how stable each measure is.
#
# Questions to answer after the simulation:
# - Which measure is most sensitive to noise?
# - How does the mode behave when you bin the noisy values (e.g. round to nearest $50)?

# %%
# Simulation parameters you can change
set.seed(42)
noise_sd <- 150          # try 50, 150, 300
n_sims   <- 200

# TODO: loop, store sim_means, sim_medians, sim_modes, then summarise / plot

# %% [markdown]
# ## Key Takeaways (fill after completing)
#
# - Mean is pulled upward by expensive outliers → use median for “typical rent.”
# - Mode shows the most frequently advertised price point.
# - Always check Mode ≤ Median ≤ Mean as a quick skew diagnostic.
# - State your assumptions when comparing boroughs.
# - Adapt the same numbers into different language for analysts vs executives vs the public.
