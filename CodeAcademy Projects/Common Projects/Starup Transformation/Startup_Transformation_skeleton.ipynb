# %% [markdown]
# # Startup Transformation - Skeleton Notebook (Practice Version)
#
# **Instructions**: Fill in the TODO sections. Run cells to practice.
#
# ## Problem Statement
# A tech startup needs post-pandemic analysis on finances, employees, and remote work.
#
# ## Flowchart
# ```mermaid
# graph TD
#     A[Load Datasets] --> B[Financial Trends]
#     B --> C[Expense Breakdown]
#     C --> D[Productivity Analysis]
#     D --> E[Commute + Transformations]
#     E --> F[Simulation Section]
#     F --> G[Final Recommendations]
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1. Load Financial Data

# %%
# TODO 1-2: Load financial_data.csv and explore
# financial_data = pd.read_csv('/home/workdir/attachments/financial_data.csv')
# print(financial_data.head())

# %% [markdown]
# ## 2. Revenue & Expenses Plots (Add labels)

# %%
# TODO 3-5: Create plots (use plt.plot, plt.clf, labels)
# Alternate: sns.lineplot

# %% [markdown]
# ## 3. Expense Pie Chart

# %%
# TODO 6-10: Load expenses.csv, create pie (collapsed categories)

# %% [markdown]
# ## 4. Employee Productivity Analysis

# %%
# TODO 12-14: Load employees.csv, sort by Productivity, cut bottom 100

# %% [markdown]
# ## 5. Commute Times

# %%
# TODO 16-20: Commute stats, histogram, log transform

# %% [markdown]
# ## 6. Extra Practice: Simulation Section

# %%
# TODO: Define simulation function for different cutoffs and plot results

# %% [markdown]
# ## 7. Key Questions

# %%
# TODO: Answer the 3 main questions based on your analysis
