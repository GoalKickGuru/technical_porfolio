# %% [markdown]
# # Getting Ready for Physics Class — Practice Skeleton Notebook
#
# **Goal:** Build a small suite of pure Python functions that a physics teacher can give students so they can quickly convert temperatures and compute force, energy, and work.
#
# You will implement the required functions step-by-step, test them with the provided values, then extend the toolkit with extra practice problems and a live simulation cell.
#
# **How to use this notebook**
# 1. Read the markdown instructions for each task.
# 2. Write your code in the corresponding code cell (replace the `TODO` / `#` comments).
# 3. Run the cell and check the printed output.
# 4. When you get stuck, open the companion **Physics_Class_Solution.ipynb**.
#
# ---
# ## Flowchart: Desired Outcome & Function Dependencies
#
# This flowchart shows the complete workflow you will implement — from temperature helpers through force/energy/work and finally the interactive simulation.
#
# ```mermaid
# flowchart TD
#     A[Start: Physics Helper Toolkit] --> B[Temperature Conversions]
#     B --> B1["f_to_c(f_temp)<br/>C = (F-32)*5/9"]
#     B --> B2["c_to_f(c_temp)<br/>F = C*(9/5)+32"]
#     B1 --> B3[Test: 100 °F → °C]
#     B2 --> B4[Test: 0 °C → °F]
#
#     A --> C[Mechanics]
#     C --> C1["get_force(mass, accel)<br/>F = m · a"]
#     C --> C2["get_energy(mass, c=3e8)<br/>E = m · c²"]
#     C1 --> C3[train_force]
#     C2 --> C4[bomb_energy]
#
#     A --> D[Work]
#     D --> D1["get_work(mass, accel, dist)<br/>W = force · distance"]
#     D1 --> D2[train_work]
#
#     C3 --> E[Formatted Print Statements]
#     C4 --> E
#     D2 --> E
#
#     E --> F[Extended Practice]
#     F --> F1[Kelvin converters]
#     F --> F2[Kinetic energy / Power]
#     F --> F3[Gravitational force]
#
#     F --> G[Interactive Simulation]
#     G --> G1[Change mass / accel / distance / c]
#     G1 --> G2[Recompute force, work, energy]
#     G2 --> G3[Compare scenarios + plots]
# ```
#
# ---

# %% [markdown]
# ## 0. Setup — Given Values
#
# Uncomment (or leave as-is) the constants that will be used in later tasks.
# These values represent a heavy GE locomotive and a 1 kg “bomb” for the energy example.

# %%
# Given constants (do not change the numbers unless you are in the Simulation section)
train_mass = 22680          # kg
train_acceleration = 10     # m/s²
train_distance = 100        # m
bomb_mass = 1               # kg

print("Setup complete. Constants ready.")
print(f"train_mass = {train_mass} kg")
print(f"train_acceleration = {train_acceleration} m/s²")
print(f"train_distance = {train_distance} m")
print(f"bomb_mass = {bomb_mass} kg")

# %% [markdown]
# ## 1. Turn Up the Temperature
#
# ### Task 1 — Fahrenheit → Celsius
# Write a function called `f_to_c` that takes an input `f_temp` (temperature in Fahrenheit) and converts it to Celsius.
#
# **Equation**
# ```
# Temp (C) = (Temp (F) - 32) * 5/9
# ```
#
# It should **return** the Celsius value.

# %%
# TODO: define f_to_c
def f_to_c(f_temp):
    # c_temp = ...
    # return c_temp
    pass

# Quick self-check (optional)
# print(f_to_c(32))   # should be 0

# %% [markdown]
# ### Task 2 — Test 100 °F
# Define a variable `f100_in_celsius` and set it equal to the value of `f_to_c(100)`.
# Print the result so you can see it.

# %%
# TODO
# f100_in_celsius = f_to_c(100)
# print(f100_in_celsius)

# %% [markdown]
# ### Task 3 — Celsius → Fahrenheit
# Write a function called `c_to_f` that takes `c_temp` and converts it to Fahrenheit.
#
# **Equation**
# ```
# Temp (F) = Temp (C) * (9/5) + 32
# ```

# %%
# TODO: define c_to_f
def c_to_f(c_temp):
    # f_temp = ...
    # return f_temp
    pass

# %% [markdown]
# ### Task 4 — Test 0 °C
# Define `c0_in_fahrenheit = c_to_f(0)` and print it.

# %%
# TODO
# c0_in_fahrenheit = c_to_f(0)
# print(c0_in_fahrenheit)

# %% [markdown]
# ## 2. Use the Force
#
# ### Task 5 — get_force
# Define a function `get_force(mass, acceleration)` that returns `mass * acceleration`.

# %%
# TODO
def get_force(mass, acceleration):
    # return ...
    pass

# %% [markdown]
# ### Task 6 — Train force
# Call `get_force` with `train_mass` and `train_acceleration`.
# Save the result to `train_force` and **print** it.

# %%
# TODO
# train_force = get_force(train_mass, train_acceleration)
# print(train_force)

# %% [markdown]
# ### Task 7 — Formatted sentence
# Print the string:
# `The GE train supplies X Newtons of force.`
# where X is replaced by the value of `train_force`.

# %%
# TODO
# print(f"The GE train supplies {train_force} Newtons of force.")
# or use .format / %

# %% [markdown]
# ### Task 8 — get_energy
# Define `get_energy(mass, c=3*10**8)`.
# It should return `mass * c ** 2`.
# (The default value of `c` is the speed of light.)

# %%
# TODO
def get_energy(mass, c=3*10**8):
    # return ...
    pass

# %% [markdown]
# ### Task 9 — Bomb energy
# Call `get_energy(bomb_mass)` (use the default `c`) and store the result in `bomb_energy`.

# %%
# TODO
# bomb_energy = get_energy(bomb_mass)
# print(bomb_energy)

# %% [markdown]
# ### Task 10 — Formatted energy sentence
# Print:
# `A 1kg bomb supplies X Joules.`
# with X replaced by `bomb_energy`.

# %%
# TODO
# print(...)

# %% [markdown]
# ## 3. Do the Work
#
# ### Task 11 — get_work
# Define `get_work(mass, acceleration, distance)`.
# Work = force × distance.
# Inside the function, first obtain the force by calling `get_force`, then multiply by `distance` and return the result.

# %%
# TODO
def get_work(mass, acceleration, distance):
    # force = get_force(...)
    # return force * distance
    pass

# %% [markdown]
# ### Task 12 — Train work
# Call `get_work(train_mass, train_acceleration, train_distance)` and save to `train_work`.

# %%
# TODO
# train_work = get_work(train_mass, train_acceleration, train_distance)
# print(train_work)

# %% [markdown]
# ### Task 13 — Final sentence
# Print:
# `The GE train does X Joules of work over Y meters.`
# where X = `train_work` and Y = `train_distance`.

# %%
# TODO
# print(...)

# %% [markdown]
# ## 4. Alternate Implementations (Practice)
#
# Once the core functions work, try rewriting them with different Python styles.
# You do **not** need to change the original functions; create new ones with the suffixes shown.
#
# ### 4a. Lambda versions

# %%
# TODO: create lambda equivalents
# f_to_c_lambda = lambda f_temp: ...
# c_to_f_lambda = lambda c_temp: ...
# get_force_lambda = lambda m, a: ...
# get_energy_lambda = lambda m, c=3e8: ...
# get_work_lambda = lambda m, a, d: ...

# Test one of them
# print(f_to_c_lambda(100))

# %% [markdown]
# ### 4b. Single-expression return (no intermediate variables)

# %%
# TODO: rewrite get_work without an intermediate force variable
def get_work_one_liner(mass, acceleration, distance):
    # return ...
    pass

# %% [markdown]
# ## 5. More Practice Exercises
#
# Complete these extra functions. They are not part of the original Codecademy project but reinforce the same ideas.
#
# ### 5.1 Kelvin conversions
# - `c_to_k(c_temp)` → Kelvin (K = C + 273.15)
# - `k_to_c(k_temp)` → Celsius
# - `f_to_k(f_temp)` → Kelvin (you may call your existing functions)

# %%
# TODO
def c_to_k(c_temp):
    pass

def k_to_c(k_temp):
    pass

def f_to_k(f_temp):
    pass

# Tests (uncomment when ready)
# print(c_to_k(0))      # 273.15
# print(k_to_c(273.15)) # 0
# print(f_to_k(32))     # 273.15

# %% [markdown]
# ### 5.2 Kinetic energy & Power
# - `get_kinetic_energy(mass, velocity)` → ½ m v²
# - `get_power(work, time)` → work / time (Watts)

# %%
# TODO
def get_kinetic_energy(mass, velocity):
    pass

def get_power(work, time):
    pass

# Example: train traveling at 20 m/s
# print(get_kinetic_energy(train_mass, 20))
# print(get_power(train_work, 10))   # if the work is done in 10 seconds

# %% [markdown]
# ### 5.3 Gravitational force (optional challenge)
# Newton’s law of universal gravitation:
# `F = G * m1 * m2 / r²`
# where `G = 6.67430e-11`.
#
# Write `get_gravitational_force(m1, m2, r)`.

# %%
# TODO
G = 6.67430e-11

def get_gravitational_force(m1, m2, r):
    pass

# Earth-Moon example (approximate)
# earth_mass = 5.972e24
# moon_mass  = 7.348e22
# distance   = 3.844e8
# print(get_gravitational_force(earth_mass, moon_mass, distance))

# %% [markdown]
# ## 6. Interactive Simulation Section
#
# Change any of the values in the cell below and re-run **all subsequent cells** to see how force, work and energy change.
#
# You can also add your own scenarios.

# %%
# ========== CHANGE THESE VALUES ==========
sim_train_mass = 22680       # kg   (try 30000 or 15000)
sim_train_accel = 10         # m/s² (try 5 or 15)
sim_train_distance = 100     # m    (try 50 or 200)
sim_bomb_mass = 1            # kg   (try 0.5 or 2)
sim_c = 3e8                  # m/s  (leave as is unless exploring relativity jokes)

# Optional extra scenarios (list of dicts)
extra_scenarios = [
    {"name": "Light metro", "mass": 5000,  "accel": 8,  "dist": 80},
    {"name": "Heavy freight", "mass": 40000, "accel": 3, "dist": 150},
]

# %% [markdown]
# ### 6.1 Recompute with the new parameters

# %%
# TODO: use your functions with the sim_ variables
# sim_force = get_force(sim_train_mass, sim_train_accel)
# sim_work  = get_work(sim_train_mass, sim_train_accel, sim_train_distance)
# sim_energy = get_energy(sim_bomb_mass, c=sim_c)

# print(f"Simulated force : {sim_force:,.0f} N")
# print(f"Simulated work  : {sim_work:,.0f} J")
# print(f"Simulated energy: {sim_energy:.3e} J")

# %% [markdown]
# ### 6.2 Compare several scenarios (loop)
# Write a small loop that prints a table for the original train + the extra scenarios.

# %%
# TODO
# print(f"{'Scenario':<15} {'Force (N)':>12} {'Work (J)':>14}")
# print("-" * 45)
# # original
# ...
# for sc in extra_scenarios:
#     f = get_force(sc["mass"], sc["accel"])
#     w = get_work(sc["mass"], sc["accel"], sc["dist"])
#     print(f"{sc['name']:<15} {f:>12,.0f} {w:>14,.0f}")

# %% [markdown]
# ### 6.3 Visualisation (optional but recommended)
# Create a simple bar chart of force (or work) for the different scenarios using `matplotlib`.

# %%
# TODO (import matplotlib.pyplot as plt first)
# names = ["Original GE"] + [sc["name"] for sc in extra_scenarios]
# forces = [get_force(train_mass, train_acceleration)] + \
#          [get_force(sc["mass"], sc["accel"]) for sc in extra_scenarios]
# 
# plt.figure(figsize=(8,4))
# plt.bar(names, forces, color=["steelblue", "orange", "green"])
# plt.ylabel("Force (N)")
# plt.title("Train Force under Different Scenarios")
# plt.xticks(rotation=15)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 7. Quick Reflection
#
# When you have finished:
#
# 1. Which function was the most interesting to write? Why?
# 2. Why is it useful to give `c` a default value in `get_energy`?
# 3. How does changing `train_acceleration` affect both force **and** work?
# 4. Can you think of a real-world situation where you would want a Kelvin converter?
#
# Write a few sentences in the cell below (or discuss with a classmate).

# %%
# Your reflections:
