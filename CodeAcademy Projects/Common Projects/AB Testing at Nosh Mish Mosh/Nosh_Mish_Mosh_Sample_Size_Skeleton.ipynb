# %% [markdown]
# # Nosh Mish Mosh: Sample Size for an Artisanal A/B Test — Practice Skeleton
#
# **Goal:** Calculate the sample size required to detect a meaningful revenue lift when Nosh Mish Mosh switches to artisanal vegetable photography.
#
# Work through each step.  Replace every `None` / `TODO` with working code.  The companion **Solution** notebook shows complete answers, alternate implementations, extra practice and a simulation playground.
#
# ---

# %% [markdown]
# ## Flowchart: Desired Outcome for the Nosh Mish Mosh Experiment
#
# This flowchart captures the full recommended process for the artisanal-vegetable A/B test.
# It emphasises **fixed-horizon** testing (run to the pre-calculated sample size) and the final step of **adapting the report to the audience** (data literacy, subject knowledge, and available time – see the supplied PDFs).
#
# ```mermaid
# flowchart TD
#     A[Start: Business Goal<br/>Increase weekly meal-plan revenue<br/>by ≥ $1 240] --> B[Gather Historical Data<br/>customer_visits, purchasing_customers,<br/>money_spent]
#     B --> C[Compute Baseline Conversion Rate<br/>paying / total × 100]
#     C --> D[Compute Revenue per Paying Customer<br/>np.mean(money_spent)]
#     D --> E[New Customers Needed for +$1 240<br/>np.ceil(1240 / avg_payment)]
#     E --> F[Percentage-Point Lift Required<br/>new_customers / total_visitors × 100]
#     F --> G[Minimum Detectable Effect MDE<br/>relative % = pp_lift / baseline × 100]
#     G --> H[Choose Significance Threshold<br/>α = 0.10 (10 %)]
#     H --> I[Look up / Calculate Required Sample Size<br/>A/B Sample Size Calculator → ≈ 490]
#     I --> J[Run Experiment to Fixed N<br/><b>Do NOT peek or stop early</b>]
#     J --> K[Analyse Results<br/>conversion rates, lift, p-value,<br/>practical significance]
#     K --> L{Statistically &amp; Practically<br/>Significant?}
#     L -->|Yes| M[Adopt Artisanal Photos<br/>&amp; New Provider]
#     L -->|No| N[Keep Current Assets<br/>or Iterate Hypothesis]
#     M --> O[Write Data-Analysis Report<br/>Tailor to Audience:<br/>• Executives – headline + ROI<br/>• Technical – methods + code<br/>• Mixed – layered sections]
#     N --> O
#     O --> P[End: Update Baseline<br/>&amp; Share Organisational Learning]
#     style J fill:#ffcccc,stroke:#cc0000
#     style O fill:#e6f3ff,stroke:#0066cc
# ```
#
# **Key takeaway (from the PDFs):** The last box is critical.  A C-level reader has little time and moderate data literacy; a data-science peer wants full methods and diagnostics.  Structure the report accordingly (Introduction → Body organised by question → Conclusion → Appendix).

# %% [markdown]
# ## Audience Considerations (from the provided PDFs)
#
# Before you write a single line of the final report, answer three questions about the people who will read it:
#
# 1. **Data Literacy**
#    - High (engineers, data scientists, psychology grads): scatter-plots, box-plots, confidence intervals are fine.
#    - Low (literature / fine-arts backgrounds): stick to bars, lines, simple percentages and friendly analogies.
#
# 2. **Subject Knowledge**
#    - Experts (finance, product, growth teams): skip definitions of EBITDA / WACC / conversion rate; they may prefer waterfall charts or profit-loss style layouts.
#    - Novices: explain every abbreviation and highlight whether an increase is good or bad.
#
# 3. **Time Span / Attention**
#    - C-level skimming a dashboard between meetings → one-sentence headline + recommendation.
#    - Same person reading a long-form magazine piece after hours → deeper narrative is acceptable.
#
# The data-analysis report structure recommended in the third PDF is ideal for mixed audiences:
#
# - **Introduction** – big questions + headline conclusions (executives stop here).
# - **Body** – one subsection per analytic question (methods → analysis → conclusion).
# - **Conclusion / Discussion** – reprise + next steps.
# - **Appendix** – full code, detailed tables, diagnostics (technical supervisors dig in here).

# %% [markdown]
# ## 1. Setup – Import the data library and NumPy
#
# Nosh Mish Mosh has exposed last week’s customer data through a Python library called `noshmishmosh`.
#
# ### TODO
# 1. Import `noshmishmosh`.
# 2. Import `numpy` as `np`.

# %%
# TODO: import the two libraries
import noshmishmosh
import numpy as np

print("Libraries loaded successfully.")

# %% [markdown]
# ## 2. Baseline Conversion Rate
#
# We need three inputs for any sample-size calculation:
#
# - Baseline conversion rate
# - Minimum Detectable Effect (desired lift)
# - Statistical significance threshold
#
# ### TODO – Steps 4-8
# 1. Assign `noshmishmosh.customer_visits` to `all_visitors`.
# 2. Assign `noshmishmosh.purchasing_customers` to `paying_visitors`.
# 3. Compute `total_visitor_count = len(all_visitors)` and `paying_visitor_count = len(paying_visitors)`.
# 4. Compute the baseline percentage:
#    ```python
#    baseline_percent = paying_visitor_count / total_visitor_count * 100.0
#    ```
# 5. Print it.

# %%
# TODO: Steps 4-8
all_visitors = None          # <-- replace
paying_visitors = None       # <-- replace

total_visitor_count = None   # <-- replace
paying_visitor_count = None  # <-- replace

baseline_percent = None      # <-- replace
print("Baseline percent:")
print(baseline_percent)

# %% [markdown]
# ## 3. Effect Size – How many extra customers do we need?
#
# The new photography costs more.  We only want to adopt it if we gain **at least $1 240** extra revenue per week.
#
# ### TODO – Steps 9-14
# 1. Load `noshmishmosh.money_spent` into `payment_history`.
# 2. Compute `average_payment = np.mean(payment_history)`.
# 3. Compute how many new customers are required:
#    ```python
#    new_customers_needed = np.ceil(1240 / average_payment)
#    ```
# 4. Convert that number into a percentage-point increase of the visitor base:
#    ```python
#    percentage_point_increase = new_customers_needed / total_visitor_count * 100
#    ```
# 5. Express the lift as a **relative** percentage of the baseline (this is the MDE):
#    ```python
#    mde = percentage_point_increase / baseline_percent * 100.0
#    ```
# 6. Print both `percentage_point_increase` and `mde`.

# %%
# TODO: Steps 9-14
payment_history = None           # <-- replace
average_payment = None           # <-- replace
new_customers_needed = None      # <-- replace
percentage_point_increase = None # <-- replace
mde = None                       # <-- replace

print("Percentage point increase:")
print(percentage_point_increase)
print("Minimum Detectable Effect:")
print(mde)

# %% [markdown]
# ## 4. Statistical Significance Threshold & Sample Size
#
# We are willing to accept a 10 % chance of a false positive (α = 0.10).
#
# ### TODO – Steps 15-16
# 1. Record the significance threshold (for documentation).
# 2. Look up the required sample size in an A/B sample-size calculator (or use the power-analysis formula).  For the classic numbers the calculator returns **490**.  Store it in `ab_sample_size`.
# 3. Print the final answer.

# %%
# TODO: Steps 15-16
significance_threshold = 0.10   # 10 %
ab_sample_size = None            # <-- replace with the calculator result

print("Required sample size (total visitors to show the new assets):")
print(ab_sample_size)

# %% [markdown]
# ## 5. Alternate Code Paths (practice)
#
# Try to obtain the **same numeric results** with different Python idioms.
#
# ### Alternate A – pure Python (no NumPy for the mean)
# ```python
# # TODO: rewrite average_payment without np.mean
# average_payment_alt = sum(payment_history) / len(payment_history)
# ```
#
# ### Alternate B – list comprehension for the baseline
# ```python
# # TODO: compute baseline using a list comprehension that counts True values
# # (imagine each visitor is a Boolean “did they purchase?”)
# ```
#
# ### Alternate C – use statsmodels to recompute sample size yourself
# ```python
# from statsmodels.stats.power import NormalIndPower
# from statsmodels.stats.proportion import proportion_effectsize
# # TODO: finish the power calculation and compare with 490
# ```

# %%
# TODO: implement at least one alternate path here
pass

# %% [markdown]
# ## 6. Extra Practice Questions
#
# 1. If the average payment rose to $30, how many new customers would be needed for the same $1 240 lift?  How would that change the MDE and the required sample size?
# 2. What happens to the required sample size if we tighten α from 0.10 to 0.05 while keeping everything else constant?
# 3. Suppose the baseline conversion is only 10 %.  Keeping the same absolute revenue target, recalculate MDE and sample size.
# 4. Write a one-paragraph “executive summary” that a C-level reader (low time, moderate data literacy) could understand in 15 seconds.

# %%
# TODO: answer the extra-practice questions in code or markdown comments
pass

# %% [markdown]
# ## 7. Simulation Playground – Change the Knobs
#
# Modify the three inputs below and re-run the cell to see how the required sample size changes.  This is the “what-if” tool product managers love.
#
# ```python
# # Knobs you can turn
# sim_baseline_pct   = 18.6          # %
# sim_mde_relative   = 50.5          # % relative lift
# sim_alpha          = 0.10
# sim_power          = 0.80
# ```
#
# Use `statsmodels` (or any other library) to recompute the sample size and print a short comparison table.

# %%
# TODO: implement the simulation
# Hint: proportion_effectsize + NormalIndPower().solve_power
pass

# %% [markdown]
# ## 8. Reflection – Audience Adaptation
#
# Write three short bullet points describing how you would present the final recommendation of “we need ~490 visitors” to each of the following audiences:
#
# - A C-level executive (30-second skim)
# - A data-science peer (full technical review)
# - A mixed group of product managers and designers (medium attention, mixed literacy)

# %%
# TODO: your reflection notes (can be comments or print statements)
print("Reflection goes here.")
