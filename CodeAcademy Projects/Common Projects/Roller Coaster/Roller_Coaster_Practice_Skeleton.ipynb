# %% [markdown]
# # Roller Coaster – Extended Practice Skeleton
#
# Use this notebook to practice. Cells contain step-by-step instructions and `# TODO` placeholders.
# Compare with the companion **Solution** notebook when you are stuck or want to see alternate approaches.

# %% [markdown]
# #### Overview
#
# This is an **extended** version of the classic Codecademy Roller Coaster visualization lab.
# You will load Golden Ticket Award rankings (wood & steel, 2013–2018) and a large roller-coaster statistics dataset, build reusable plotting functions, discover patterns (manufacturer specialties, seating-type effects, height–speed relationship), try alternate coding approaches, and run a small simulation by changing key parameters.

# %% [markdown]
# #### Project Goals
#
# 1. Master pandas filtering + matplotlib/seaborn line, bar, hist, pie and scatter plots.
# 2. Write parameterized functions for ranking trends of 1 / 2 / top-n coasters.
# 3. Explore real coaster statistics (speed, height, length, inversions).
# 4. Identify patterns: popular seating types, manufacturer focus areas, park specialties.
# 5. Practice alternate implementations and a parameter-driven simulation.
# 6. Produce clear visual insights and a 1-page summary report.

# %% [markdown]
# ## Prerequisites
#
# You should be comfortable with the first lessons of **Data Analysis with Pandas** and **Data Visualization in Python** (matplotlib). Knowledge of `groupby`, filtering with boolean masks, and basic function writing will help.

# %% [markdown]
# ## Analysis Pipeline Flowchart
#
# ![Roller Coaster Analysis Flowchart](roller_coaster_flowchart.png)
#
# The flowchart above outlines the extended analysis pipeline: load rankings & coaster stats → ranking-over-time visualizations → distributions & categorical plots → pattern mining (manufacturers, seating, parks) → alternate implementations → simulation of parameters → insights & report.

# %% [markdown]
# ## Project Requirements – Core + Extensions
#
# ### 1. Load Rankings Data
# Roller coasters are split into **wood** and **steel**. Rankings from the 2013–2018 Golden Ticket Awards are in:
# - `Golden_Ticket_Award_Winners_Wood.csv`
# - `Golden_Ticket_Award_Winners_Steel.csv`
#
# **Tasks**
# - Import `pandas` and `matplotlib.pyplot`.
# - Load both CSVs into DataFrames (`wood_rankings`, `steel_rankings`).
# - Print `.head()` and `.shape` / `.columns` for each.

# %%
# 1 – TODO
# Import necessary libraries

# load rankings data (wood)

# load rankings data (steel)

# inspect

# %% [markdown]
# ### 2. Ranking of One Coaster Over Time
# Write a function `plot_coaster_ranking(coaster_name, rankings_df, park_name=None)` that plots rank vs. year for a given coaster.
#
# - If the same name appears in multiple parks, use the optional `park_name` argument to filter.
# - Invert the y-axis so rank 1 is at the top.
# - Add title, xlabel, ylabel, legend.
#
# **Call it** with `"El Toro"` and the wood DataFrame. What issue appears? Fix it with the park argument (Six Flags Great Adventure).

# %%
# 2 – TODO
def plot_coaster_ranking(coaster_name, rankings_df, park_name=None):
    # filter by name (and optionally park)
    # plot Year of Rank vs Rank
    # invert y-axis, labels, show
    pass

# Create a plot of El Toro ranking over time

# %% [markdown]
# ### 3. Ranking of Two Coasters Over Time
# Write `plot_two_coasters(name1, name2, rankings_df, park1=None, park2=None)`.
#
# Call with `"El Toro"` and `"Boulder Dash"` on the wood rankings (supply parks if needed).

# %%
# 3 – TODO
def plot_two_coasters(name1, name2, rankings_df, park1=None, park2=None):
    pass

# Create a plot of El Toro and Boulder Dash

# %% [markdown]
# ### 4. Top-n Rankings Over Time
# Write `plot_top_n(rankings_df, n=5)`.
#
# Plot a line for every coaster that ever achieved a rank ≤ n.
# Call it for wood with `n=5` and for steel with `n=3`.

# %%
# 4 – TODO
def plot_top_n(rankings_df, n=5):
    pass

# Create a plot of top n rankings over time

# %% [markdown]
# ### 5. Load Roller-Coaster Statistics
# Load `roller_coasters.csv` into a DataFrame `roller_coasters`.
# Inspect shape, columns, dtypes, missing values, and value counts of `status`, `material_type`, `seating_type`.

# %%
# 5 – TODO
# load roller coaster data

# inspect

# %% [markdown]
# ### 6. Histograms of Numeric Columns
# Write `plot_histogram(df, column)`.
# Call it for `speed`, `length`, `num_inversions`.
# Also write a special `plot_height_histogram` that filters unrealistic heights (e.g. height < 140) before plotting.

# %%
# 6 – TODO
def plot_histogram(df, column):
    pass

# Create histogram of roller coaster speed
# Create histogram of roller coaster length
# Create histogram of roller coaster number of inversions

def plot_height_histogram(df, max_height=140):
    pass

# Create a histogram of roller coaster height

# %% [markdown]
# ### 7. Inversions by Coaster at a Park
# Write `plot_inversions_by_coaster(df, park_name)`.
# Bar chart of `num_inversions` for every coaster at that park.
# Try `"Parc Asterix"` or `"Cedar Point"`.

# %%
# 7 – TODO
def plot_inversions_by_coaster(df, park_name):
    pass

# Create barplot of inversions by roller coasters

# %% [markdown]
# ### 8. Operating vs Closed Pie Chart
# Write `plot_status_pie(df)` comparing `status.operating` vs `status.closed.definitely` (ignore other statuses or group them).

# %%
# 8 – TODO
def plot_status_pie(df):
    pass

# Create pie chart of roller coasters

# %% [markdown]
# ### 9. Scatter Plots
# Write `plot_scatter(df, col_x, col_y)`.
# Also write a specialized `plot_speed_vs_height(df)` that drops rows with height ≥ 140 and missing values.

# %%
# 9 – TODO
def plot_scatter(df, column_x, column_y):
    pass

def plot_speed_vs_height(df, max_height=140):
    pass

# Create a scatter plot of roller coaster height by speed

# %% [markdown]
# ## More Practice – Pattern Discovery
#
# Answer these questions with code + plots:
#
# **A.** What seating type is most common? Do different seating types tend to be faster / taller / longer?
#
# **B.** Do manufacturers have specialties? (Compare average speed, height, inversions for manufacturers with ≥ 10 coasters.)
#
# **C.** Which parks have the most recorded coasters? Any park that specializes in high-inversion or hyper coasters?
#
# **D.** Correlation matrix / heatmap of the four numeric columns.

# %%
# More Practice A – seating popularity & stats
# TODO: value_counts of seating_type
# TODO: groupby seating_type → mean speed / height / length

# %%
# More Practice B – manufacturer specialties
# TODO: groupby manufacturer, filter count >= 10, sort by avg speed

# %%
# More Practice C – park specialties
# TODO

# %%
# More Practice D – correlation heatmap
# TODO: use seaborn.heatmap or matplotlib imshow on .corr()

# %% [markdown]
# ## Alternate Code Approaches
#
# Re-implement **one** of the earlier functions using a different style:
#
# - Use `seaborn` (`sns.lineplot` / `sns.histplot`) instead of pure matplotlib.
# - Use method chaining (`.query().groupby()...`).
# - Use `pivot_table` for the top-n ranking plot.

# %%
# Alternate – e.g. seaborn version of ranking or histogram
# TODO
import seaborn as sns
# ...

# %% [markdown]
# ## Simulation Section
#
# Modify a few parameters and observe how results change.
#
# 1. Choose different `n` for top-n rankings (n=3 vs n=10) – which coasters appear/disappear?
# 2. Change the height filter threshold (100 m vs 200 m) and re-plot the speed-vs-height scatter; does the correlation change?
# 3. Simulate a “popularity score” = `0.4*speed_norm + 0.3*height_norm + 0.3*inversions_norm` and rank the top 10 coasters by this synthetic score. Change the weights and see the new ranking.

# %%
# Simulation 1 – different top-n
# TODO: call plot_top_n with different n

# %%
# Simulation 2 – height threshold effect on correlation
# TODO

# %%
# Simulation 3 – synthetic popularity score
# TODO: normalize columns, compute weighted score, show top 10
# Try weights (0.5, 0.3, 0.2) vs (0.2, 0.5, 0.3) etc.

# %% [markdown]
# ## Open-Ended Exploration
#
# Come up with one additional question of your own (e.g. “Do wooden coasters ever receive high ranks in steel awards?” or “How has average points of the #1 wood coaster changed?”) and answer it with a visualization.

# %%
# Your own question
# TODO
