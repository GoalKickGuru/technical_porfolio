# %% [markdown]
# # Skeleton Notebook: Website Visitors Linear Regression
#
# Follow the steps. Fill in the code.
#
# **Flowchart:**
# ```mermaid
# graph TD
#     A[Load Data] --> B[Scatter time vs age]
#     B --> C[Fit Model age]
#     C --> D[Plot Line]
#     D --> E[Residuals & Diagnostics]
#     E --> F[Predict 40yo]
#     F --> G[Browser Model]
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
website = pd.read_csv('/home/workdir/attachments/website.csv')
print(website.head())
