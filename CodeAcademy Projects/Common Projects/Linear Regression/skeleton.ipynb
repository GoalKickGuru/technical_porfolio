# %% [markdown]
# # Skeleton Notebook: Simple Linear Regression with Student Data
#
# ## Objective
# Build a simple linear regression model to predict `score` from `hours_studied` and explore the effect of `breakfast`.
#
# Follow the step-by-step markdown instructions. Fill in the code cells.
#
# **Flowchart of the process:**
# ```mermaid
# graph TD
#     A[Load Data] --> B[Explore Data]
#     B --> C[Fit Linear Model]
#     C --> D[Make Predictions]
#     D --> E[Evaluate with Residuals]
#     E --> F[Visualize]
#     F --> G[Analyze Categorical Variable]
# ```

# %%
# TODO 1: Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# TODO 2: Read the data
students = pd.read_csv('/home/workdir/attachments/test_data.csv')
print(students.head())

# %% [markdown]
# ## Step 1: Visualize the relationship
# Create a scatter plot of hours_studied vs score. Add a manual line.

# %%
# TODO: Scatter plot and manual line (use approx slope 9.85, intercept 43)
plt.scatter(...)  # fill
plt.plot(...) 
plt.show()

# %% [markdown]
# ## Step 2: Fit the OLS model
# Use statsmodels to fit score ~ hours_studied

# %%
# TODO: Fit model
model = sm.OLS.from_formula('...', data=students)
results = model.fit()
print(results.params)

# %% [markdown]
# ## Step 3: Predictions
# Predict for 3 and 5 hours.

# %%
# TODO: Predictions
pred_3hr = ...
print(pred_3hr)
# Use results.predict for 5hr

# %% [markdown]
# ## Step 4: Residuals and Diagnostics
# Calculate fitted and residuals, plot histogram and scatter.

# %%
# TODO: Fitted and residuals

# Plots

# %% [markdown]
# ## Step 5: Breakfast Analysis
# Compare means and fit model with breakfast.

# %%
# TODO: Group means and OLS for breakfast

# %% [markdown]
# ## More Practice and Simulation
# Modify data or parameters and re-run.

# %%
# Simulation TODO
