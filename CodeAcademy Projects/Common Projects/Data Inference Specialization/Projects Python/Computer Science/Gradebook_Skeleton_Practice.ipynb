# %% [markdown]
# # Gradebook Organizer - Skeleton Notebook (Practice)
#
# ## Objective
# Use Python lists to organize subjects and grades. Practice creating 2D lists, appending, modifying, removing, combining lists, and adding analysis features.
#
# **Flowchart of Desired Outcome** (Mermaid):
# ```mermaid
# flowchart TD
#     A[Start] --> B[Create subjects list]
#     B --> C[Create grades list]
#     C --> D[Build 2D gradebook manually]
#     D --> E[Print gradebook]
#     E --> F[Append new subjects/grades]
#     F --> G[Modify grades (e.g. +5 points)]
#     G --> H[Change poetry to Pass/Fail]
#     H --> I[Combine with last semester]
#     I --> J[Analysis: average, highest, lowest]
#     J --> K[Simulation: random grades loop]
#     K --> L[End]
# ```
#
# ### Instructions
# Complete each TODO. Run cells sequentially. Compare with the Solution notebook.

# %% [markdown]
# ### Step 1: Create subjects List
# subjects = ["physics", "calculus", "poetry", "history"]

# %%
# TODO
# subjects = [...]

# %% [markdown]
# ### Step 2: Create grades List
# grades = [98, 97, 85, 88]

# %%
# TODO
# grades = [...]

# %% [markdown]
# ### Step 3: Create 2D gradebook (Manually)
# gradebook = [["physics", 98], ["calculus", 97], ...]

# %%
# TODO: Build 2D list manually
# gradebook = [...]

# %% [markdown]
# ### Step 4: Print gradebook
# Verify it matches the expected table.

# %%
# TODO: print(gradebook)

# %% [markdown]
# ### Step 5: Append Computer Science (100)
# Use .append(["computer science", 100])

# %%
# TODO

# %% [markdown]
# ### Step 6: Append Visual Arts (93)
# Use .append(["visual arts", 93])

# %%
# TODO

# %% [markdown]
# ### Step 7: Modify Visual Arts Grade (+5 points)
# Access by index and add 5.

# %%
# TODO: Find index and modify

# %% [markdown]
# ### Step 8 & 9: Change Poetry to Pass/Fail
# Remove the numeric grade and append "Pass".

# %%
# TODO: .remove() then .append("Pass")

# %% [markdown]
# ### Step 10: Combine with last_semester_gradebook
# full_gradebook = last_semester_gradebook + gradebook

# %%
# TODO: Create last_semester and combine

# %% [markdown]
# ### Step 11: Analysis Functions (New)
# Add functions to calculate average, find highest/lowest grade.

# %%
# TODO: def calculate_average(gradebook): ...

# %% [markdown]
# ### Step 12: Simulation Section
# Loop over random weights or generate sample gradebooks. Modify parameters.

# %%
# TODO: Simulation loop with random grades

# %% [markdown]
# ### Step 13: Alternate Implementations
# Try using a dictionary instead of 2D list.

# %%
# TODO: gradebook_dict = {...}

# %% [markdown]
# ## How to Practice
# Fill TODOs → Run cells → Verify outputs → Modify simulation values → Compare with Solution notebook.
#
# This expanded version adds analysis, functions, simulation, and alternate data structures.
