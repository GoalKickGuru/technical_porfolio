# %% [markdown]
# # Magic 8-Ball Fortune Teller - Skeleton Notebook (Practice Version)
#
# ## Objective
# Build a Python program that simulates a Magic 8-Ball toy. It answers "Yes/No" questions with random fortunes.
# Expand it with user input, more answers, error handling, and simulations.
#
# **Flowchart of Desired Outcome** (Text representation - copy to Mermaid live editor for visual):
# ```mermaid
# flowchart TD
#     A[Start] --> B[Import random]
#     B --> C[Get name and question from user]
#     C --> D{Question empty?}
#     D -->|Yes| E[Print: Please ask a question!]
#     D -->|No| F[Generate random_number = randint(1,12)]
#     F --> G[if-elif chain to map number to fortune]
#     G --> H[Handle empty name]
#     H --> I[Print formatted output]
#     I --> J[Simulation: Loop multiple times with different questions]
#     J --> K[End]
# ```
#
# ### Step-by-Step Instructions
# Follow these markdown steps. Fill in the code cells yourself.

# %% [markdown]
# ### Step 1: Setup and Imports
# Import the random module.

# %%
# TODO: Import random module
# import random

# %% [markdown]
# ### Step 2: Declare Variables
# - name: string for the person asking (can be empty)
# - question: the Yes/No question
# - answer: empty string initially
# - random_number: to be generated

# %%
# TODO: Declare variables
# name = "Your Name"
# question = "Will I win the lottery?"
# answer = ""
# random_number = 0

# %% [markdown]
# ### Step 3: Generate Random Number
# Use random.randint(1, 12) for expanded range.

# %%
# TODO: Generate random number
# random_number = random.randint(1, 12)
# print("Random number:", random_number)  # Debug, comment later

# %% [markdown]
# ### Step 4: Control Flow - if/elif/else for Fortunes
# Map 1-12 to different answers. Include the original 9 + 3 new ones.

# %%
# TODO: if-elif-else chain
# if random_number == 1:
#     answer = "Yes - definitely"
# elif random_number == 2:
#     answer = "It is decidedly so"
# ... continue for 3 to 12
# else:
#     answer = "Error"

# %% [markdown]
# ### Step 5: Formatted Output
# Print exactly:
# [Name] asks: [Question]
# Magic 8-Ball's answer: [Answer]
# Handle empty name.

# %%
# TODO: Print statements with if for name
# if not name.strip():
#     print("Question:", question)
# else:
#     print(name + " asks: " + question)
# print("Magic 8-Ball's answer:", answer)

# %% [markdown]
# ### Practice Section: Alternate Code
# Try implementing using a list of fortunes + indexing instead of long if-chain.

# %%
# TODO: Alternate implementation
# fortunes = ["Yes - definitely", ... ]
# answer = fortunes[random_number - 1]

# %% [markdown]
# ### Simulation Section
# Add a loop to run multiple simulations. Modify num_simulations and questions list.

# %%
# TODO: Simulation loop
# num_simulations = 5  # Modify this
# questions_list = ["Will it rain?", "Should I learn Python?"]
# for i in range(num_simulations):
#     q = random.choice(questions_list)
#     # reuse logic or function
#     print(f"Simulation {i+1}: {q} -> {answer}")

# %% [markdown]
# ## How to Use This Notebook
# 1. Fill in each TODO code cell.
# 2. Run cells sequentially (Shift+Enter).
# 3. Compare with the Solution Notebook.
# 4. Modify simulation values to see different results.
#
# **Audience Tip**: When sharing this tool, consider data literacy of your audience (simple output for non-experts).
