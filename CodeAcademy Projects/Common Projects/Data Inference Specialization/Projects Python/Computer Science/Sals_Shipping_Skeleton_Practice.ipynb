# %% [markdown]
# # Sal's Shipping Cost Calculator - Skeleton Notebook (Practice)
#
# ## Objective
# Build a Python program that calculates the cheapest shipping method for a package based on its weight using Sal’s Shippers options:
# - Ground Shipping
# - Ground Shipping Premium
# - Drone Shipping
#
# **Flowchart of Desired Outcome** (Mermaid - paste into live editor):
# ```mermaid
# flowchart TD
#     A[Start] --> B[Get package weight]
#     B --> C{Calculate Ground cost}
#     C --> D{Calculate Premium cost}
#     D --> E{Calculate Drone cost}
#     E --> F[Compare all three costs]
#     F --> G[Print cheapest method + price]
#     G --> H{Simulation mode?}
#     H -->|Yes| I[Loop over multiple weights]
#     H -->|No| J[End]
#     I --> J
# ```
#
# ### Instructions
# Complete each TODO section. Run cells to test. Compare with Solution notebook.

# %% [markdown]
# ### Step 1: Define Weight Variable
# Set a weight variable to test (e.g. 8.4 or 41.5).

# %%
# TODO: Define weight
# weight = 8.4

# %% [markdown]
# ### Step 2: Ground Shipping Calculation
# Write if/elif/else for ground shipping cost using the rate table.
# Comment: # Ground Shipping

# %%
# TODO: Ground Shipping
# if weight <= 2:
#     cost_ground = weight * 1.5 + 20
# elif weight <= 6:
#     ...
# else:
#     ...
# print("Ground Shipping: $", cost_ground)

# %% [markdown]
# ### Step 3: Test Ground Shipping
# Verify with 8.4 lb → should be $53.60

# %%
# TODO: Test your ground calculation here

# %% [markdown]
# ### Step 4: Ground Shipping Premium
# Create a variable for the flat $125 premium cost (no weight dependency).

# %%
# TODO: Premium
# cost_premium = 125
# print("Ground Shipping Premium: $", cost_premium)

# %% [markdown]
# ### Step 5: Drone Shipping
# Write if/elif/else for drone (rates are 3x ground, no flat fee).
# Comment: # Drone Shipping

# %%
# TODO: Drone Shipping
# if weight <= 2:
#     cost_drone = weight * 4.5
# elif ...
# print("Drone Shipping: $", cost_drone)

# %% [markdown]
# ### Step 6: Test Drone Shipping
# Verify with 1.5 lb → should be $6.75

# %%
# TODO: Test drone calculation

# %% [markdown]
# ### Step 7: Find the Cheapest Method
# Compare the three costs and print the cheapest option + price.

# %%
# TODO: Compare costs
# if cost_ground < cost_premium and cost_ground < cost_drone:
#     print("Cheapest: Ground Shipping $", cost_ground)
# elif ...

# %% [markdown]
# ### Step 8: User Input (Make it Interactive)
# Use input() to ask for package weight.

# %%
# TODO: Get weight from user
# weight = float(input("Enter package weight in lbs: "))

# %% [markdown]
# ### Step 9: Create a Reusable Function
# Wrap the logic in a function `calculate_shipping(weight)` that returns the cheapest method and cost.

# %%
# TODO: def calculate_shipping(weight): ...

# %% [markdown]
# ### Step 10: Simulation Section
# Loop over several weights and print cheapest for each. Modify the list of test weights.

# %%
# TODO: Simulation
# test_weights = [1.5, 4.8, 8.4, 41.5]
# for w in test_weights:
#     # calculate and print cheapest

# %% [markdown]
# ### Step 11: Alternate Code Approaches
# Try implementing rates using a dictionary or list instead of long if-chains.

# %%
# TODO: Alternate implementation using dict or list of rates

# %% [markdown]
# ## How to Practice
# 1. Fill TODOs one by one.
# 2. Run and verify outputs match expected values.
# 3. Modify simulation weights to see different cheapest methods.
# 4. Compare your code with the Solution notebook.
#
# **Tip**: Consider your audience when presenting this tool (data literacy, time constraints, etc.).
