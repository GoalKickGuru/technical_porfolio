# %% [markdown]
# # [Optional] Practice with selecting
#
# Use these code exercises to practice with selecting! These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with SQL.

# %% [markdown]
# ## Database
#
# In these code-block exercises, you will be working with a database representing a digital media store. The data schema available on Code Blocks is slightly different from the one you saw on the Demos. All the instructions and the following image contain the correct schema for these exercises.

# %% [markdown]
# ## Data Schema
#
# ![data schema](data-schema.png)

# %% [markdown]
# ## **Exercise 1: Selecting all columns**
#
# You want to understand the customer base and their details. You can begin by retrieving all the features of customers in your dataset.

# %% [markdown]
# ## Instructions:
#
# 1. Write a SQLite query to return all columns from the **customers** table with no limit

# %%
select * from customers;
# Out:
# +------------------------------------------------------------------------------+
# | Cus |     |     |     |     |     |     |     | Pos |     |     |     |      |
# | tom | Fir | Las | Com | Add |     |     | Cou | tal |     |     |     | Supp |
# | erI | stN | tNa | pan | res | Cit | Sta | ntr | Cod | Pho |     | Ema | ortR |
# |   d | ame | me  | y   | s   | y   | te  | y   | e   | ne  | Fax | il  | epId |
# |-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+-----+------|
# |   1 | Luí | Gon | Emb | Av. | São | SP  | Bra | 122 | +55 | +55 | lui |    3 |
# |     | s   | çal | rae | Bri | Jos |     | zil | 27- | (12 | (12 | sg@ |      |
# |     |     | ves | r - | gad | é   |     |     | 000 | )   | )   | emb |      |
# |     |     |     | Emp | eir | dos |     |     |     | 392 | 392 | rae |      |
# |     |     |     | res | o   | Cam |     |     |     | 3-5 | 3-5 | r.c |      |
# |     |     |     | a   | Far | pos |     |     |     | 555 | 566 | om. |      |
# ...

# %% [markdown]
# **Expected output:**
#
# ![expected output](optional-practice-with-selecting-output.png)
#
# **Hints:**
#
# - The SELECT statement followed by an asterisk (*) selects all the columns from a table
# - The FROM statement is used to select the table you want to retrieve the information from, in this case the **customers** table
# - Don't forget to close the query with a semicolon (;)

# %% [markdown]
# ## **Exercise 2: Selecting specific columns**
#
# Your company wants to know if it makes sense to expand your business to other cities. To shine some light into this question you want to focus on the billing country in the invoices

# %% [markdown]
# ## Instructions
#
# Write a SQLite query that:
#
# - Selects the **BillingCountry** column
# - From the **invoices** table

# %% [markdown]
# **Expected output:**
#
# ```
# +--------------------+
# | BillingCountry     |
# +--------------------+
# | Germany            |
# | Norway             |
# | Belgium            |
# | Canada             |
# | USA                |
# | Germany            |
# | Germany            |
# | France             |
# | France             |
# | Ireland            |
# | United Kingdom     |
# | Germany            |
# | USA                |
# | USA                |
# | USA                |
# | USA                |
# | USA                |
# | Canada             |
# | France             |
# | United Kingdom     |
# | Australia          |
# | Chile              |
# | India              |
# | Norway             |
# | Brazil             |
# +--------------------+
# (Output limit exceeded, 25 of 412 total rows shown)
# ```
#
# **Hints:**
#
# - You can use the SELECT statement followed by the name of the column you want to select
# - The FROM statement is used to select the table you want to retrieve the information from, in this case the **invoices** table
# - Don't forget to close the query with a semicolon (;)

# %% [markdown]
# ## SOLUTIONS:
#
# ### Exercise 1:
#
# ```sql
# select * from customers;
# ```
#
# ### Exercise 2:
#
# ```sql
# select BillingCountry from invoices;
# ```
