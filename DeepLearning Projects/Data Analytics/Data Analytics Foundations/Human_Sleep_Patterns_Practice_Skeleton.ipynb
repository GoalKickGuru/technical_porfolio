# %% [markdown]
# # Human Sleep Patterns & Stress — Practice Skeleton Notebook
#
# **Goal:** Practice analyzing wearable sleep-tracker data and performing a one-sided hypothesis test for a proportion. Follow the step-by-step markdown instructions and fill in the code cells marked with `# TODO`.
#
# **How to use this notebook:**
# 1. Read each markdown instruction carefully.
# 2. Complete the code cells (look for `# TODO`).
# 3. Run the cell and verify the printed output.
# 4. When stuck, consult the companion *Solution* notebook.
# 5. After finishing the main exercise, attempt the Alternate, More Practice and Simulation sections.
#
# **Data file needed:** `human_sleep_patterns.csv` (already provided in the project folder).

# %% [markdown]
# ## Project Flowchart
#
# ![Human Sleep Flowchart](human_sleep_flowchart.png)

# %% [markdown]
# ## 0. Setup & Imports
#
# **Task:** Import `pandas`, `numpy`, `matplotlib.pyplot`, `seaborn`, `scipy.stats`, and `proportions_ztest` from `statsmodels.stats.proportion`. Optionally set a plotting style and enable inline plots.
#
# **Hint:**
# ```python
# import pandas as pd
# ...
# from statsmodels.stats.proportion import proportions_ztest
# %matplotlib inline
# ```

# %%
# TODO: import the required libraries
# import pandas as pd
# import numpy as np
# ...

print("Libraries loaded successfully.")  # replace once imports are done

# %% [markdown]
# ## 1. Load & Explore the Data
#
# **Task:**
# 1. Load `human_sleep_patterns.csv` into a DataFrame called `df`, parsing the `DATE` column as datetime.
# 2. Sort by DATE and reset the index.
# 3. Print shape, date range, column names, head, describe, and missing-value counts.

# %%
# TODO: load and prepare the data
# df = pd.read_csv(...)
# df = df.sort_values(...).reset_index(drop=True)

# TODO: inspect
# print("Shape:", ...)
# print date range, columns, head, describe, isnull().sum()

# %% [markdown]
# ## 2. Exercise 1 — Hours of Sleep (Hypothesis Test for a Proportion)
#
# It is known that you need at least 7 hours of sleep per night for a healthy lifestyle. We will test whether the friend sleeps ≥ 7 hours **at least 75 % of the time**.
#
# ### 2.1 Set up the hypotheses
#
# **Task:** Write the null and alternative hypotheses and state whether the test is two-tailed, right-tailed or left-tailed.
#
# - H₀: …
# - H₁: …
# - Type of test: …

# %%
# TODO: (optional) record the hypotheses as comments
# H0: p = 0.75
# H1: p > 0.75
# This is a right-tailed test.

# %% [markdown]
# ### 2.2 Compute count, n and p-hat
#
# **Task:**
# - Count the number of days where `HOURS OF SLEEP >= 7` (use a boolean mask and `.sum()`).
# - Obtain the sample size `n = len(df)`.
# - Compute the sample proportion `phat = count / n`.
# - Print all three values.

# %%
# TODO: count, n, phat
# count = ...
# n = ...
# phat = ...
# print them

# %% [markdown]
# ### 2.3 Test statistic
#
# **Task:** Calculate the z test statistic
#
# \[ z = \frac{\hat{p} - p_0}{\sqrt{p_0(1-p_0)/n}} \]
#
# where \( p_0 = 0.75 \). Print the standard error and the z-statistic.

# %%
# TODO: se and z_stat
p0 = 0.75
# se = np.sqrt(...)
# z_stat = (phat - p0) / se
# print se and z_stat

# %% [markdown]
# ### 2.4 p-value and decision
#
# **Task:**
# 1. Compute the right-tailed p-value using the standard normal CDF: `1 - stats.norm.cdf(z_stat)`.
# 2. Decide whether to reject H₀ at α = 0.05 and at α = 0.10. Print clear statements.

# %%
# TODO: p_value
# p_value = ...
# print(p_value)

# TODO: decision statements for alpha = 0.05 and 0.10

# %% [markdown]
# ## 3. Alternate Code Paths (same result)
#
# ### 3.1 statsmodels proportions_ztest
#
# **Task:** Re-compute the same one-sided test with `proportions_ztest(count, n, value=0.75, alternative='larger', prop_var=0.75)`. Print z and p-value.

# %%
# TODO: use proportions_ztest
# z_sm, p_sm = proportions_ztest(...)
# print(...)

# %% [markdown]
# ### 3.2 Exact binomial test
#
# **Task:** Use `stats.binomtest` (or the older `stats.binom_test`) with `alternative='greater'` to obtain an exact p-value. Compare it with the normal-approximation p-value.

# %%
# TODO: exact binomial p-value
# try:
#     res = stats.binomtest(...)
#     binom_p = res.pvalue
# except ...
# print(binom_p)

# %% [markdown]
# ## 4. More Practice Problems
#
# ### 4.1 One-sample t-test for mean hours
#
# **Task:** Test H₀: μ = 7 vs H₁: μ > 7 with `stats.ttest_1samp(..., alternative='greater')`. Print mean, t-statistic and p-value.

# %%
# TODO: one-sample t-test
# mean_hours = ...
# t_stat, p_t = stats.ttest_1samp(...)
# print results

# %% [markdown]
# ### 4.2 Proportion of high Sleep-Score nights (≥ 85)
#
# **Task:** Test whether the proportion of nights with Sleep Score ≥ 85 is greater than 0.50. Use `proportions_ztest`.

# %%
# TODO: high-score proportion test
# count_high = ...
# z_high, p_high = proportions_ztest(...)
# print results

# %% [markdown]
# ### 4.3 Correlation matrix
#
# **Task:** Compute the Pearson correlation matrix among the numeric sleep metrics and print the correlations of Sleep Score with the other variables (sorted).

# %%
# TODO: correlation matrix and ranking
# corr_matrix = df[[...]].corr()
# print(...)

# %% [markdown]
# ## 5. Pattern Discovery
#
# ### 5.1 Monthly summary table
#
# **Task:** Create a month column, then group by month and compute:
# - number of nights
# - number of nights ≥ 7 h
# - mean hours, mean score, mean REM, mean Deep
# - proportion ≥ 7 h
#
# Print the resulting table and note any months that look weaker.

# %%
# TODO: monthly aggregation
# df['month'] = ...
# monthly = df.groupby('month').agg(...).reset_index()
# monthly['prop_ge7'] = ...
# print(monthly)

# %% [markdown]
# ### 5.2 Visualizations
#
# **Task:** Display the four pre-generated charts (`sleep_hours_dist.png`, `sleep_score_scatter.png`, `sleep_monthly_prop.png`, `sleep_corr_heatmap.png`) using `IPython.display.Image`.

# %%
# TODO: display the four images
# from IPython.display import Image, display
# display(Image('sleep_hours_dist.png'))
# ...

# %% [markdown]
# ## 6. Simulation Section
#
# ### 6.1 Sensitivity to the hours threshold
#
# **Task:** Write a small function (or simply loop) that, for thresholds 6.5, 7.0, 7.5 and 8.0, recomputes count, p-hat, z and p-value (p0 fixed at 0.75). Print a neat summary and observe when the decision flips.

# %%
# TODO: loop over thresholds and print results
# for thr in [6.5, 7.0, 7.5, 8.0]:
#     ...

# %% [markdown]
# ### 6.2 Sensitivity to p0
#
# **Task:** Keep the threshold at 7 h and vary p0 over {0.70, 0.75, 0.80, 0.85}. Print z, p-value and reject decision for each.

# %%
# TODO: loop over different p0 values

# %% [markdown]
# ### 6.3 Bootstrap 95 % CI
#
# **Task:** Draw 5 000 bootstrap samples of the “hours ≥ 7” indicator, compute the percentile CI for the true proportion, and check whether 0.75 falls inside it.

# %%
# TODO: bootstrap CI
# np.random.seed(42)
# boot_phats = []
# for _ in range(5000):
#     ...
# ci_low, ci_high = np.percentile(...)
# print CI and comment

# %% [markdown]
# ### 6.4 Approximate power (true p = 0.80)
#
# **Task (stretch):** Approximate the power of the current test when the true proportion is 0.80 (α = 0.05). You may use the normal approximation formulas shown in the solution notebook.

# %%
# TODO (optional): power calculation

# %% [markdown]
# ## 7. Reflection
#
# After finishing the notebook, answer briefly:
#
# 1. Did you reject H₀ at 5 %? at 10 %?
# 2. What is the practical takeaway for the friend?
# 3. Which additional insight (monthly pattern, correlation, simulation) did you find most interesting?
